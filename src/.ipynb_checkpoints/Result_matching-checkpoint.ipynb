# %% [markdown]
# # Phase3 : Result Matching
#
# In phase 3 we will match the organization names extracted using the selected Named Entity Recognition (NER) Tools with those listed by the Crossref Funder Registry.
#
#
# ## NER Tools
# The organization names are extracted from the funding statement using the following NER tools -
#
# 1) spaCy (en_core_web_sm)
#
# 2) spaCy (en_core_web_md)
#
# 3) spaCy (en_core_web_lg)
#
# 4) Flair (from Zolando Research)
#
# All the NER tools have been trained on data in English.
#
# The details for NER tools from spaCy are available here - https://spacy.io/models/en
#
# The details from NER tools from flair are available here - https://github.com/flairNLP/flair
#
# ## Cossref Funder Registry
#
# The Crossref Funder Registry also has a curated list of funding organizations which are acknowledged in research papers for their support and contribution in research work. We have extracted all these names and arranged them in alphabetical order in a dictionary.

# %%
import timeit
t_0 = timeit.default_timer()

# %% [markdown]
# **1. Importing required libraries**

# %%
import numpy as np
import pandas as pd
import os
import csv
import re
import pickle
# module for extracting all the organization names from ".rdf" downloaded from -
# https://gitlab.com/crossref/open_funder_registry
import Crossref_funding_organization_extraction_dict_creation

# %% [markdown]
# **2. Importing NER tool results**
#
# A pickle file containing the organizations names extracted from the selected biomedical research papers is the frist input to the result matching code. A each tool extracts a list of organizations from the funding statements in these research papers.

# %%
# input file path
ner_filepath = "../data/ack_ner.pickle"

# load the data pickle file
with open(ner_filepath, 'rb') as handle:
    ner_data = pickle.load(handle)

ner_data.drop(columns = ['index'], inplace = True)
ner_data.head()
# Out:
#                                        Article_Title   PMC_ID  \
# 0  Impact of antibiotics on the human microbiome ...  8756738
# 1  Novel nitrite reductase domain structure sugge...  8756737
# 2  Efficacy of antifungal agents against fungal s...  8756736
# 3  Assembly and comparative analysis of the first...  8756732
# 4  Characterizing the effects of different chemic...  8756731
#
#                           DOI  \
# 0                          na
# 1                          na
# 2                          na
# 3  10.1186/s12870-021-03416-5
# 4  10.1186/s13007-021-00835-1
#
#                                      acknowledgement  \
# 0  The authors were funded in part by Science Fou...
# 1  The authors thank Dr. Ranjani Murali for advic...
# 2  This study was funded by Dr. Pfleger Arzneimit...
# 3  Thanks to all the members of the Institute of ...
# 4  Not applicable. This work was supported by the...
#
#                           NER_Spacy (en_core_web_sm)  \
# 0  {'ORG': ['Science Foundation Ireland'], 'GPE':...
# 1  {'PERSON': ['Ranjani Murali', 'Sarah L. Schwar...
# 2  {'PERSON': ['Pfleger Arzneimittel GmbH'], 'GPE...
# 3  {'ORG': ['the Institute of Leisure Agriculture...
# 4  {'ORG': ['the National Research Foundation', '...
#
#                           NER_Spacy (en_core_web_md)  \
# 0  {'ORG': ['Science Foundation Ireland'], 'GPE':...
# 1  {'PERSON': ['Ranjani Murali', 'Sarah L. Schwar...
# 2  {'ORG': ['Dr. Pfleger Arzneimittel GmbH', 'Pro...
# 3  {'ORG': ['the Institute of Leisure Agriculture...
# 4  {'ORG': ['the National Research Foundation', '...
#
#                           NER_Spacy (en_core_web_lg)  \
# 0  {'ORG': ['Science Foundation Ireland'], 'GPE':...
# 1  {'PERSON': ['Ranjani Murali', 'Sarah L. Schwar...
# 2  {'ORG': ['Pfleger Arzneimittel GmbH', 'Projekt...
# 3  {'ORG': ['the Institute of Leisure Agriculture...
# 4  {'ORG': ['the National Research Foundation', '...
#
#                                            NER_Flair  \
# 0  {'ORG': ['Science Foundation Ireland', 'APC Mi...
# 1  {'PER': ['Ranjani Murali', 'Sarah L. Schwartz'...
# 2  {'ORG': ['Dr. Pfleger Arzneimittel GmbH'], 'LO...
# 3  {'ORG': ['Institute of Leisure Agriculture', '...
# 4  {'ORG': ['National Research Foundation', 'NRF'...
#
#                                     NER_spacy_sm_org  \
# 0                       [Science Foundation Ireland]
# 1  [a National Defense Science and Engineering Gr...
# 2                                                 NA
# 3  [the Institute of Leisure Agriculture, the Gen...
# 4      [the National Research Foundation, NRF, MSIT]
#
#                                     NER_spacy_md_org  \
# 0                       [Science Foundation Ireland]
# 1  [a National Defense Science and Engineering Gr...
# 2      [Dr. Pfleger Arzneimittel GmbH, Projekt DEAL]
# 3  [the Institute of Leisure Agriculture, theÂ Mi...
# 4            [the National Research Foundation, NRF]
#
#                                     NER_spacy_lg_org  \
# 0                       [Science Foundation Ireland]
# 1  [a National Defense Science and Engineering Gr...
# 2               [Pfleger Arzneimittel GmbH, Projekt]
# 3  [the Institute of Leisure Agriculture, theÂ, M...
# 4            [the National Research Foundation, NRF]
#
#                                        NER_Flair_org
# 0  [Science Foundation Ireland, APC Microbiome Ir...
# 1                                                 NA
# 2                    [Dr. Pfleger Arzneimittel GmbH]
# 3  [Institute of Leisure Agriculture, Genepioneer...
# 4          [National Research Foundation, NRF, MSIT]

# %% [markdown]
# **3. Importing Crossref Funder Registry Results**
#
# The Crossref funder registry maintains a list organization names which it stores in a ".rdf" file. We have implmenented a module to extract all the organization names and store them into a dictionary with keys as the starting alphabet of each name.

# %%
# storing the funding organization data in a dictonary
orga_dict = Crossref_funding_organization_extraction_dict_creation.funder_dictionary_creation("../data/registry.rdf")

# priting first 10 names from all the keys.
for ele in orga_dict:
    print(ele, orga_dict[ele][:10])
# Out:
# a ['administración de alimentos y medicamentos de los estados unidos', "american parkinson's disease foundation", 'apda', 'american diabetes association', 'asociación americana de la diabetes', 'ada', 'amgen foundation', 'amgen foundation, inc.', 'amgen foundation inc', 'american association for cancer research']
# b ['boeing', 'boeing company', 'boeing co', 'boeing co.', 'biological sciences (bio)', 'bio', 'bio/oad', 'bio/mcb', 'biological infrastructure', 'bio/dbi']
# c ['centers for disease control and prevention', 'centers for disease control & prevention', 'centros para el control y la prevención de enfermedades', 'centers for disease control', 'cdc', 'computer and information science and engineering', 'cise', 'cise/oad', 'congressionally directed medical research programs', 'cdmrp']
# d ['department of defense', 'dod', "department of the navy's office of naval research", 'david and lucile packard foundation', 'david & lucile packard foundation', 'dlpf', 'department of energy', 'doe', 'department of health and human services', 'dhhs']
# e ['energy department', 'energy.gov', 'el instituto nacional de investigación dental y craneofacial', 'el departamento de justicia de ee. uu.', 'education and human resources', 'ehr', 'ehr/oad', 'ehr/dge', 'eng', 'eng/oad']
# f ['foundation for the national institutes of health', 'foundation for the national institutes of health, inc.', 'foundation for the nih', 'foundation for the national institutes of health inc', 'foundation for nih', 'fnih', 'ford foundation', 'ford foundation center for social justice', 'fordfoundation', 'ford']
# g ['graduate education (dge)', 'geo', 'geo/oad', 'geo/opp', 'gesundheitsressourcen und dienstleistungen verwaltung', 'geo/oce', 'geo/ags', 'geo/ear', 'geo/opp/ant', 'geo/opp/arc']
# h ['howard hughes medical institute', 'hhmi', 'hhs', 'health resources and services administration', 'health resources & services administration', 'hrsa', 'human resource development', 'hrd', 'homeland security', 'housing and urban development department']
# i ['institutos nacionales de la salud', 'instituto nacional de la salud mental', 'instituto nacional sobre el abuso de drogas de estados unidos', 'instituto nacional sobre el abuso de drogas', 'instituto nacional del cáncer', 'instituto nacional de la sordera y otros trastornos de la comunicación', 'instituto nacional de alergias y enfermedades infecciosas', 'instituto nacional de trastornos neurológicos y accidentes cerebrovasculares', 'instituto nacional de artritis y enfermedades musculoesqueléticas y de la piel', 'instituto nacional de imágenes biomédicas y bioingeniería']
# j ['john e. fogarty international center', 'john edward fogarty international center', 'justice department', 'john d. and catherine t. macarthur foundation', 'john d. & catherine t. macarthur foundation', 'john d & catherine t macarthur foundation', 'jdctmf', 'juvenile diabetes research foundation international', 'juvenile diabetes research foundation, international', 'jdrf']
# k ['kauffman foundation', 'keck foundation', 'kalliopeia foundation', 'kavli foundation', 'kessler foundation', 'kettering fund', 'knights templar eye foundation', 'kt eye foundation', 'knights templar eye foundation, inc.', 'knights templar eye foundation inc']
# l ['labor department', 'lynde and harry bradley foundation', 'lynde & harry bradley foundation', 'lynde and harry bradley foundation, inc.', 'lynde and harry bradley foundation inc', 'lynde and harry bradley foundation incorporated', 'lhbf', 'la fundación comunitaria de arizona', 'lance armstrong foundation', 'laf']
# m ['mental health nimh', 'materials research (dmr)', 'mps/dmr', 'mathematical and physical sciences', 'mps', 'mps/oad', 'mathematical sciences', 'molecular and cellular biosciences', 'molecular & cellular biosciences', 'mcb']
# n ['national science foundation', 'nsf', 'national institutes of health', 'nih', 'naval research', 'national hemophilia foundation', 'nhf', 'national institute of mental health', 'nimh', 'national institute on drug abuse']
# o ['office of naval research', 'onr', 'office of the director', 'office of the nih director', 'office of the director, nih', 'od', 'office of dietary supplements', 'oficina de suplementos dietéticos', 'ods', 'office of polar programs']
# p ['packard foundation', 'pf', 'polar programs', 'phy', 'pehs', 'pew charitable trusts', 'pew', 'pct', 'prostate cancer foundation', 'pcf']
# q ['quixote foundation', 'quixote foundation, inc.', 'quick start - the eddie kennison foundation', 'quaker', 'qualcomm', 'quiktrip', 'qt', 'quinco consulting center', 'questcor pharmaceuticals', 'quality enhancement research initiative']
# r ['resous ak sèvis sante administrasyon', 'research on learning in formal and informal settings', 'robert r. mccormick foundation', 'rrm foundations', 'robert r. mccormick foundations', 'robert r mccormick foundation', 'robert wood johnson foundation', 'rwj foundation', 'rwjf', 'rockefeller foundation']
# s ['smithsonian institution', 'smithsonian', 'si', 'semiconductor research corporation', 'semiconductor research corp.', 'semiconductor research corp', 'src', 'sociedad americana contra el cáncer', 'substance abuse and mental health services administration', 'substance abuse & mental health services administration']
# t ['the boeing company', 'the office of naval research', 'the david and lucile packard foundation', 'the david & lucile packard foundation', 'the foundation for the nih', 'the foundation for the national institutes of health', 'the smithsonian institution', 'the u.s. department of health & human services', 'the national hemophilia foundation', 'the national institute on drug abuse']
# u ['us nsf', 'usa nsf', 'u.s. department of defense', 'united states department of defense', 'u.s. dept of defense', 'us department of defense', 'us dept of defense', 'usdod', 'us office of naval research', 'u.s. office of naval research']
# v ['veterans affairs', 'veterans affairs department', 'va', 'v foundation for cancer research', 'v foundation', 'vfcr', 'valley foundation', 'van wert county foundation', 'van wert county foundation, inc.', 'vanwertco foundation']
# w ['woodrow wilson international center for scholars', 'wilson center', 'woodrow wilson center', 'wilson (woodrow) international center for scholars', 'wwics', 'w. m. keck foundation', 'w.m. keck foundation', 'w m keck foundation', 'wm keck foundation', 'wmkf']
# x ['xerox foundation', 'xerox', 'xerox corporation', 'xinjiang natural science foundation', 'xiamen municipal bureau of science and technology', 'xiamen science and technology bureau', 'xiamen bureau of science and technology', 'xoran technologies', 'xavier university of louisiana', 'xu']
# y ['youth foundation', 'yamaha', 'yaddo', 'yale university', 'yale', 'yale university beinecke rare book & manuscript library', 'yale university. beinecke rare book and manuscript library', 'yale center for british art, yale university', 'yale center for british art', 'yale center for british art, new haven, ct']
# z ['zasoby i usługi zdrowotne administracja', "zachary and elizabeth m. fisher center for alzheimer's research foundation", "zachary & elizabeth m. fisher center for alzheimer's research foundation", "zachary & elizabeth m fisher center for alzheimer's research foundation/", "zachary and elizabeth m. fisher center for alzheimer's research", 'zyvex corporation', 'z. smith reynolds foundation', 'z. smith reynolds foundation, inc.', 'z smith reynolds foundation inc', 'z smith reynolds fdn']
# other ['卫生资源和服务管理局', '보건 자원 및 서비스 관리', 'есурсов и служб здравоохранения администрации', '保健資源およびサービス管理 保', 'منابع و مدیریت خدمات بهداشتی', 'مؤسسة جون تمبلتون', '哈佛燕京学社', '1675 foundation', 'アジアン・カルチュラル・カウンシル', '아시아 문화 협회']

# %% [markdown]
# We will use a reference count to compare the number of organizations names matching between Crossref Funder Registry and the NER tool output. This reference count is the number of unique organizations names present in the Crossref Funder Registry

# %%
ref_count = 0
for ele in orga_dict.values():
    ref_count+= len(ele)
print("The number of unique organization from the Crossref Funder Registry used for result matching:", ref_count)
# Out:
# The number of unique organization from the Crossref Funder Registry used for result matching: 94226

# %%
print("The columns of the ner dataframe are:", ner_data.columns)
ner_data.head()
# Out:
# The columns of the ner dataframe are: Index(['Article_Title', 'PMC_ID', 'DOI', 'acknowledgement',
#        'NER_Spacy (en_core_web_sm)', 'NER_Spacy (en_core_web_md)',
#        'NER_Spacy (en_core_web_lg)', 'NER_Flair', 'NER_spacy_sm_org',
#        'NER_spacy_md_org', 'NER_spacy_lg_org', 'NER_Flair_org'],
#       dtype='object')
#                                        Article_Title   PMC_ID  \
# 0  Impact of antibiotics on the human microbiome ...  8756738
# 1  Novel nitrite reductase domain structure sugge...  8756737
# 2  Efficacy of antifungal agents against fungal s...  8756736
# 3  Assembly and comparative analysis of the first...  8756732
# 4  Characterizing the effects of different chemic...  8756731
#
#                           DOI  \
# 0                          na
# 1                          na
# 2                          na
# 3  10.1186/s12870-021-03416-5
# 4  10.1186/s13007-021-00835-1
#
#                                      acknowledgement  \
# 0  The authors were funded in part by Science Fou...
# 1  The authors thank Dr. Ranjani Murali for advic...
# 2  This study was funded by Dr. Pfleger Arzneimit...
# 3  Thanks to all the members of the Institute of ...
# 4  Not applicable. This work was supported by the...
#
#                           NER_Spacy (en_core_web_sm)  \
# 0  {'ORG': ['Science Foundation Ireland'], 'GPE':...
# 1  {'PERSON': ['Ranjani Murali', 'Sarah L. Schwar...
# 2  {'PERSON': ['Pfleger Arzneimittel GmbH'], 'GPE...
# 3  {'ORG': ['the Institute of Leisure Agriculture...
# 4  {'ORG': ['the National Research Foundation', '...
#
#                           NER_Spacy (en_core_web_md)  \
# 0  {'ORG': ['Science Foundation Ireland'], 'GPE':...
# 1  {'PERSON': ['Ranjani Murali', 'Sarah L. Schwar...
# 2  {'ORG': ['Dr. Pfleger Arzneimittel GmbH', 'Pro...
# 3  {'ORG': ['the Institute of Leisure Agriculture...
# 4  {'ORG': ['the National Research Foundation', '...
#
#                           NER_Spacy (en_core_web_lg)  \
# 0  {'ORG': ['Science Foundation Ireland'], 'GPE':...
# 1  {'PERSON': ['Ranjani Murali', 'Sarah L. Schwar...
# 2  {'ORG': ['Pfleger Arzneimittel GmbH', 'Projekt...
# 3  {'ORG': ['the Institute of Leisure Agriculture...
# 4  {'ORG': ['the National Research Foundation', '...
#
#                                            NER_Flair  \
# 0  {'ORG': ['Science Foundation Ireland', 'APC Mi...
# 1  {'PER': ['Ranjani Murali', 'Sarah L. Schwartz'...
# 2  {'ORG': ['Dr. Pfleger Arzneimittel GmbH'], 'LO...
# 3  {'ORG': ['Institute of Leisure Agriculture', '...
# 4  {'ORG': ['National Research Foundation', 'NRF'...
#
#                                     NER_spacy_sm_org  \
# 0                       [Science Foundation Ireland]
# 1  [a National Defense Science and Engineering Gr...
# 2                                                 NA
# 3  [the Institute of Leisure Agriculture, the Gen...
# 4      [the National Research Foundation, NRF, MSIT]
#
#                                     NER_spacy_md_org  \
# 0                       [Science Foundation Ireland]
# 1  [a National Defense Science and Engineering Gr...
# 2      [Dr. Pfleger Arzneimittel GmbH, Projekt DEAL]
# 3  [the Institute of Leisure Agriculture, theÂ Mi...
# 4            [the National Research Foundation, NRF]
#
#                                     NER_spacy_lg_org  \
# 0                       [Science Foundation Ireland]
# 1  [a National Defense Science and Engineering Gr...
# 2               [Pfleger Arzneimittel GmbH, Projekt]
# 3  [the Institute of Leisure Agriculture, theÂ, M...
# 4            [the National Research Foundation, NRF]
#
#                                        NER_Flair_org
# 0  [Science Foundation Ireland, APC Microbiome Ir...
# 1                                                 NA
# 2                    [Dr. Pfleger Arzneimittel GmbH]
# 3  [Institute of Leisure Agriculture, Genepioneer...
# 4          [National Research Foundation, NRF, MSIT]

# %%
match_count_spacy_sm_org = 0
match_result_spacy_sm_org = []
match_NER_spacy_sm_org = {}
for pmcid, orga_list in zip(ner_data['PMC_ID'], ner_data['NER_spacy_sm_org']):
    temp = []
    for orga in orga_list:
        orga = orga.lower()
        if orga[0] in orga_dict.keys() and orga in orga_dict[orga[0]]:
            temp.append(orga)
    match_NER_spacy_sm_org[pmcid] = temp

# %%
match_count_spacy_md_org = 0
match_result_spacy_md_org = []
match_NER_spacy_md_org = {}
for pmcid, orga_list in zip(ner_data['PMC_ID'], ner_data['NER_spacy_md_org']):
    temp = []
    for orga in orga_list:
        orga = orga.lower()
        if orga[0] in orga_dict.keys() and orga in orga_dict[orga[0]]:
            temp.append(orga)
            match_count_spacy_md_org += 1
            match_result_spacy_md_org.append(orga)
    match_NER_spacy_md_org[pmcid] = temp

# %%
match_count_spacy_lg_org = 0
match_result_spacy_lg_org = []
match_NER_spacy_lg_org = {}
for pmcid, orga_list in zip(ner_data['PMC_ID'], ner_data['NER_spacy_lg_org']):
    temp = []
    for orga in orga_list:
        orga = orga.lower()
        if orga[0] in orga_dict.keys() and orga in orga_dict[orga[0]]:
            temp.append(orga)
            match_count_spacy_lg_org += 1
            match_result_spacy_lg_org.append(orga)
    match_NER_spacy_lg_org[pmcid] = temp

# %%
match_count_flair_org = 0
match_result_flair_org = []
match_NER_flair_org = {}
for pmcid, orga_list in zip(ner_data['PMC_ID'], ner_data['NER_Flair_org']):
    temp = []
    for orga in orga_list:
        orga = orga.lower()
        if orga[0] in orga_dict.keys() and orga in orga_dict[orga[0]]:
            temp.append(orga)
            match_count_flair_org += 1
            match_result_flair_org.append(orga)
    match_NER_flair_org[pmcid] = temp

# %%
NER_spacy_sm_match = pd.DataFrame(zip(match_NER_spacy_sm_org.keys(),
                                      ner_data['acknowledgement'],
                                      match_NER_spacy_sm_org.values()),
                                      
                                      columns = ['PMC_ID', 'Acknowledgement', 'Match']
                                     )
NER_spacy_md_match = pd.DataFrame(zip(match_NER_spacy_md_org.keys(),
                                      ner_data['acknowledgement'],
                                      match_NER_spacy_md_org.values()),
                                     
                                     columns = ['PMC_ID', 'Acknowledgement', 'Match']
                                     )
NER_spacy_lg_match = pd.DataFrame(zip(match_NER_spacy_lg_org.keys(),
                                      ner_data['acknowledgement'],
                                      match_NER_spacy_lg_org.values()),
                                     
                                    columns = ['PMC_ID', 'Acknowledgement', 'Match']
                                     )
NER_flair_match = pd.DataFrame(zip(match_NER_flair_org.keys(),
                                   ner_data['acknowledgement'],
                                   match_NER_flair_org.values()),
                                  
                                   columns = ['PMC_ID', 'Acknowledgement', 'Match']
                                  )
with pd.ExcelWriter('match_orga.xlsx') as writer:
    NER_spacy_sm_match.to_excel(writer, sheet_name='NER_spacy_sm_org', index = False)
    NER_spacy_md_match.to_excel(writer, sheet_name='NER_spacy_md_org', index = False)
    NER_spacy_lg_match.to_excel(writer, sheet_name='NER_spacy_lg_org', index = False)
    NER_flair_match.to_excel(writer, sheet_name='NER_Flair_org', index = False)

# %% [markdown]
# **4. Preprocessing the text to increase the match count**
#
# We have developed 4 preprocessing functions which have been sequentially applied to the tool and funder registry results. The functions are defined in the cell below.

# %%
def case_lowering(text : str) -> str:
    """
    Lower case strings in a text
    :param text: input raw text
    :return text_updated: lower_cased string
    """
    text_updated = text.lower()
    return text_updated

# %%
def det_removal(text : str) -> list:
    """
    Removing the determiners (a, an, the) from the begining of the string
    :param text: input raw text
    :return updated_text: list containing string with articles removed from the begining and new start letter
    """
    text_updated = ""
    det_list = ['a', 'an', 'the']
    if text == 'the' or text == 'a' or text == 'an':
        text_updated = text
    elif text.split(" ")[0] in det_list:
            text_updated = " ".join(text.split(" ")[1:])
    else:
        text_updated = text
    updated_text = [text_updated, text_updated[0]]
    return updated_text

# %%
def and_replacement(text : str) -> str:
    """
    Replacing "and" with "&" in the text
    :param text: input raw text
    :return text_updated: text with 'and' replaced with '&' if any
    """
    text_updated = re.sub(" and ", " & ", text)
    return text_updated

# %%
def punct_removal(text : str) -> str:
    """
    Removing punctuation marks from the text
    :param text: input raw text
    :return text_updated: text with punctuations and special symbols removed except '&'
    """
    regex = r"[!\"#\$%\'\(\)\*\+,-\./:;<=>\?@\[\\\]\^_`{\|}~]"
    text_updated = re.sub(regex, "", text)
    return text_updated

# %% [markdown]
# **5. Result Matching**
#
# We will now match the results from the NER tool out and Crossref Funder Registry using the preprocessing functions sequentially

# %%
def text_processing(ner_data : pd.DataFrame, tool : str) -> list:
    """
    Arranging all the organization names identified by a specific tool into a list
    :param ner_data: data series containing all the organization of identified by the tool under consideration
    :param tool: name of the NER tool used for extracting organization names
    :return new_tool_org: list of all the extracted organization names
    """
    new_tool_org = []
    for ele in ner_data[tool]:
        if type(ele) == list:
            new_tool_org+=ele
    # new_tool_org_set = set(new_tool_org)
    new_tool_org = [ele for ele in new_tool_org if ele!= " " or ele != ""]
    return  new_tool_org

# %%
def result_matching(ner_tool_set, orga_dict):
    """Matching the count of organizations between the NER tools output and crossref funder registry
    :param ner_tool_set: list of all the extracted organization names by a specific NER tool
    :param orga_dict: dictionary containing names of all the funding organization arrange alphabetically
    :return match_count: count of the number matches between NER tool output and Corssref Funder Registry
    :return match_result: list of all the matches between NER tool output and Corssref Funder Registry
    
    """
    match_count = 0
    match_result = []
    for ele in ner_tool_set:
        if ele != '' and ele[0] in orga_dict:
            for ele1 in set(orga_dict[ele[0]]):  
                if ele == ele1:
                    match_result.append(ele)
                    match_count+=1
    return match_count, match_result

# %%
# initalizing dictionaries and data frame to store the results
result_match_count = {}
result_match = {}

result_df = pd.DataFrame(columns = ['NER_spacy_sm_org', 
                                    'NER_spacy_sm_org_match',
                                    'NER_spacy_sm_org_match_%', 
                                    'NER_spacy_md_org',
                                    'NER_spacy_md_org_match',
                                    'NER_spacy_md_org_match_%',
                                    'NER_spacy_lg_org', 
                                    'NER_spacy_lg_org_match',
                                    'NER_spacy_lg_org_match_%',
                                    'NER_Flair_org', 
                                    'NER_Flair_org_match',
                                    'NER_Flair_org_match_%'],
                        index = ['Crossref baseline vs NER baseline',
                                 'Crossref baseline vs NER improved version I',
                                 'Crossref baseline vs NER improved version II',
                                 'Crossref baseline vs NER improved version III',
                                 'Crossref baseline vs NER improved version IV',
                                 'NER baseline vs Crossref improved version I',
                                 'NER baseline vs Crossref improved version II',
                                 'NER baseline vs Crossref improved version III',
                                 'NER baseline vs Crossref improved version IV',
                                 'NER improved version I vs Crossref improved version I',
                                 'NER improved version II vs Crossref improved version II',
                                 'NER improved version III vs Crossref improved version III',
                                 'NER improved version IV vs Crossref improved version IV'   
                                ])

# %% [markdown]
# **I. NER Baseline vs Crossref Baseline**
# We will first start with a baselie comparison. The baseline model in the both cases will be a lower-cased list of organization names.
#
# The models compared here are -
#
# 1) NER baseline model
#
# 2) Crossref baseline model

# %%
result_match_count['Crossref baseline vs NER baseline'] = {}
result_match['Crossref baseline vs NER baseline'] = {}
tool_output = {}

tool_names = ner_data.columns[-4:]
for tool in tool_names:
    tool_output[tool] = set([case_lowering(ele) for ele in text_processing(ner_data, tool)])
    match_count, match_result = result_matching(tool_output[tool],orga_dict)
    result_match_count['Crossref baseline vs NER baseline'][tool] = int(len(tool_output[tool]))
    result_match_count['Crossref baseline vs NER baseline'][tool+"_match"] = int(match_count)
    result_match_count['Crossref baseline vs NER baseline'][tool+"_match_%"] = match_count*100/len(tool_output[tool])
    result_match['Crossref baseline vs NER baseline'][tool] = match_result
    print("The match count between Crossref baseline model and " + tool + " baseline model :")
    print(match_count)
# Out:
# The match count between Crossref baseline model and NER_spacy_sm_org baseline model :
# 7762
# The match count between Crossref baseline model and NER_spacy_md_org baseline model :
# 8045
# The match count between Crossref baseline model and NER_spacy_lg_org baseline model :
# 8071
# The match count between Crossref baseline model and NER_Flair_org baseline model :
# 11682

# %%
ner_not_crossref = {}
for tool in tool_names:
    temp =[]
    for name in tool_output[tool]:
        if name not in result_match['Crossref baseline vs NER baseline'][tool]:
            temp.append(name)
    ner_not_crossref[tool] = temp

# %%
pd.DataFrame(orga_dict['n']).to_csv('n.csv')

# %%
print(result_match['Crossref baseline vs NER baseline']['NER_spacy_sm_org'][:10])
print(result_match['Crossref baseline vs NER baseline']['NER_spacy_md_org'][:10])
print(result_match['Crossref baseline vs NER baseline']['NER_spacy_lg_org'][:10])
print(result_match['Crossref baseline vs NER baseline']['NER_Flair_org'][:10])
# Out:
# ['national taiwan ocean university', 'global health', 'innovate uk', 'laqv', 'fmd', 'industrial technology research institute', 'hospital universiti sains malaysia', 'royal institute of technology', 'dh', 'shanghai municipal health and family planning commission']
# ['national taiwan ocean university', 'global health', 'innovate uk', 'laqv', 'industrial technology research institute', 'national council for scientific and technological development', 'royal institute of technology', 'dh', 'tsgh', 'beth israel deaconess medical center']
# ['national taiwan ocean university', 'global health', 'innovate uk', 'fmd', 'industrial technology research institute', 'hospital universiti sains malaysia', 'national council for scientific and technological development', 'mdic', 'royal institute of technology', 'mazums']
# ['shinshu university', 'loughborough university', 'zaozhuang university', 'international tennis federation', 'national taiwan ocean university', 'seoul national university', 'hasso plattner foundation', 'the university of manchester', 'sppu', 'kreitman school of advanced graduate studies']

# %%
NER_spacy_sm_org = pd.DataFrame(ner_not_crossref['NER_spacy_sm_org'], columns = ['NER_spacy_sm_org'])
NER_spacy_md_org = pd.DataFrame(ner_not_crossref['NER_spacy_md_org'], columns = ['NER_spacy_md_org'])
NER_spacy_lg_org = pd.DataFrame(ner_not_crossref['NER_spacy_lg_org'], columns = ['NER_spacy_lg_org'])
NER_Flair_org = pd.DataFrame(ner_not_crossref['NER_Flair_org'], columns = ['NER_Flair_org'])

# %%
with pd.ExcelWriter('output.xlsx') as writer:
    NER_spacy_sm_org.to_excel(writer, sheet_name='NER_spacy_sm_org')
    NER_spacy_md_org.to_excel(writer, sheet_name='NER_spacy_md_org')
    NER_spacy_lg_org.to_excel(writer, sheet_name='NER_spacy_lg_org')
    NER_Flair_org.to_excel(writer, sheet_name='NER_Flair_org')

# %%
print(ner_not_crossref['NER_spacy_sm_org'][:10])
print(ner_not_crossref['NER_spacy_md_org'][:10])
print(ner_not_crossref['NER_spacy_lg_org'][:10])
print(ner_not_crossref['NER_Flair_org'][:10])
# Out:
# ['sheetal', 'the ethics committee of', 'the international maize and wheat improvement center', 'tll temple endowed chair', 'the data intensive research enabling clean technology', 'y. escobar', 'the california breast cancer research grants program office of the university of california', 'the national coronial information system', 'jlg', 'the victorian breast cancer research consortium']
# ['tll temple endowed chair', 'italfarmaco (milan,', 'the data intensive research enabling clean technology', 'the california breast cancer research grants program office of the university of california', 'the cincinnati childrenâ\x80\x99s hospital', 'the national coronial information system', 'prosperity for all', 'metainsight', 'jlg', 'the victorian breast cancer research consortium']
# ['bdw (dsi/', 'the data intensive research enabling clean technology', 'the california breast cancer research grants program office of the university of california', 'the national coronial information system', 'jlg', 'the victorian breast cancer research consortium', 'ipgmer', 'lanuola asiasiga', 'tulane university brain institute', 'c.c.).']
# ['novelren', 'c.f.k', 'lerdc', 'national science and technology project of china', 'pilot plant department', 'italian research council', 'k.g.w.', 'central japan lung study group', 'cas de les corts', 'stiftung fã']

# %%
result_df.loc['Crossref baseline vs NER baseline'] = pd.Series(result_match_count['Crossref baseline vs NER baseline'])

# %%
ner_data
# Out:
#                                            Article_Title   PMC_ID  \
# 0      Impact of antibiotics on the human microbiome ...  8756738
# 1      Novel nitrite reductase domain structure sugge...  8756737
# 2      Efficacy of antifungal agents against fungal s...  8756736
# 3      Assembly and comparative analysis of the first...  8756732
# 4      Characterizing the effects of different chemic...  8756731
# ...                                                  ...      ...
# 65829  Selenium Induces Pancreatic Cancer Cell Death ...  8773897
# 65830  Neuropsychiatric Manifestations of Antiphospho...  8773877
# 65831  Systemic Delivery of mLIGHT-Armed Myxoma Virus...  8773855
# 65832  STAT3 Enhances Sensitivity of Glioblastoma to ...  8773829
# 65833  Implant Survival, Clinical Outcome and Complic...  8773828
#
#                               DOI  \
# 0                              na
# 1                              na
# 2                              na
# 3      10.1186/s12870-021-03416-5
# 4      10.1186/s13007-021-00835-1
# ...                           ...
# 65829                          na
# 65830                          na
# 65831                          na
# 65832                          na
# 65833                          na
#
#                                          acknowledgement  \
# 0      The authors were funded in part by Science Fou...
# 1      The authors thank Dr. Ranjani Murali for advic...
# 2      This study was funded by Dr. Pfleger Arzneimit...
# 3      Thanks to all the members of the Institute of ...
# 4      Not applicable. This work was supported by the...
# ...                                                  ...
# 65829  This work, in part was supported by Penn State...
# 65830        This research received no external funding.
# 65831  We thank Leslie Sharp, Stephen Potts, Kavita M...
# 65832  We thank Hildegard KÃ¶nig for excellent techni...
# 65833  We wish to acknowledge that author T.S.-B. was...
#
#                               NER_Spacy (en_core_web_sm)  \
# 0      {'ORG': ['Science Foundation Ireland'], 'GPE':...
# 1      {'PERSON': ['Ranjani Murali', 'Sarah L. Schwar...
# 2      {'PERSON': ['Pfleger Arzneimittel GmbH'], 'GPE...
# 3      {'ORG': ['the Institute of Leisure Agriculture...
# 4      {'ORG': ['the National Research Foundation', '...
# ...                                                  ...
# 65829  {'ORG': ['Penn State Cancer Institute Funds'],...
# 65830                                                 {}
# 65831  {'PERSON': ['Leslie Sharp', 'Stephen Potts', '...
# 65832  {'PERSON': ['Hildegard KÃ¶nig'], 'ORG': ['the ...
# 65833  {'PERSON': ['T.S.-B.'], 'ORG': ['the Universit...
#
#                               NER_Spacy (en_core_web_md)  \
# 0      {'ORG': ['Science Foundation Ireland'], 'GPE':...
# 1      {'PERSON': ['Ranjani Murali', 'Sarah L. Schwar...
# 2      {'ORG': ['Dr. Pfleger Arzneimittel GmbH', 'Pro...
# 3      {'ORG': ['the Institute of Leisure Agriculture...
# 4      {'ORG': ['the National Research Foundation', '...
# ...                                                  ...
# 65829     {'ORG': ['Penn State Cancer Institute Funds']}
# 65830                                                 {}
# 65831  {'PERSON': ['Leslie Sharp', 'Stephen Potts', '...
# 65832  {'PERSON': ['Hildegard KÃ¶nig'], 'ORG': ['the ...
# 65833  {'ORG': ['the University of Muenster Medical S...
#
#                               NER_Spacy (en_core_web_lg)  \
# 0      {'ORG': ['Science Foundation Ireland'], 'GPE':...
# 1      {'PERSON': ['Ranjani Murali', 'Sarah L. Schwar...
# 2      {'ORG': ['Pfleger Arzneimittel GmbH', 'Projekt...
# 3      {'ORG': ['the Institute of Leisure Agriculture...
# 4      {'ORG': ['the National Research Foundation', '...
# ...                                                  ...
# 65829  {'ORG': ['Penn State Cancer Institute Funds', ...
# 65830                                                 {}
# 65831  {'PERSON': ['Leslie Sharp', 'Stephen Potts', '...
# 65832  {'PERSON': ['Hildegard KÃ¶nig', 'D.K.', 'D.K.'...
# 65833  {'ORG': ['T.S.-B.', 'the University of Muenste...
#
#                                                NER_Flair  \
# 0      {'ORG': ['Science Foundation Ireland', 'APC Mi...
# 1      {'PER': ['Ranjani Murali', 'Sarah L. Schwartz'...
# 2      {'ORG': ['Dr. Pfleger Arzneimittel GmbH'], 'LO...
# 3      {'ORG': ['Institute of Leisure Agriculture', '...
# 4      {'ORG': ['National Research Foundation', 'NRF'...
# ...                                                  ...
# 65829  {'ORG': ['Penn State Cancer Institute'], 'LOC'...
# 65830                                                 {}
# 65831  {'PER': ['Leslie Sharp', 'Stephen Potts', 'Kav...
# 65832  {'PER': ['Hildegard KÃ ¶ nig'], 'ORG': ['Smart...
# 65833  {'PER': ['T.S. - B.'], 'ORG': ['University of ...
#
#                                         NER_spacy_sm_org  \
# 0                           [Science Foundation Ireland]
# 1      [a National Defense Science and Engineering Gr...
# 2                                                     NA
# 3      [the Institute of Leisure Agriculture, the Gen...
# 4          [the National Research Foundation, NRF, MSIT]
# ...                                                  ...
# 65829                [Penn State Cancer Institute Funds]
# 65830                                                 NA
# 65831  [Arizona State University, an ASU PhD Completi...
# 65832  [the Graphical Abstract, Smart Servier Medical...
# 65833  [the University of Muenster Medical School (Po...
#
#                                         NER_spacy_md_org  \
# 0                           [Science Foundation Ireland]
# 1      [a National Defense Science and Engineering Gr...
# 2          [Dr. Pfleger Arzneimittel GmbH, Projekt DEAL]
# 3      [the Institute of Leisure Agriculture, theÂ Mi...
# 4                [the National Research Foundation, NRF]
# ...                                                  ...
# 65829                [Penn State Cancer Institute Funds]
# 65830                                                 NA
# 65831  [Arizona State University, ASU, G.M., NIH, G.M...
# 65832  [the Graphical Abstract, Smart Servier Medical...
# 65833  [the University of Muenster Medical School (Po...
#
#                                         NER_spacy_lg_org  \
# 0                           [Science Foundation Ireland]
# 1      [a National Defense Science and Engineering Gr...
# 2                   [Pfleger Arzneimittel GmbH, Projekt]
# 3      [the Institute of Leisure Agriculture, theÂ, M...
# 4                [the National Research Foundation, NRF]
# ...                                                  ...
# 65829          [Penn State Cancer Institute Funds, R.S.]
# 65830                                                 NA
# 65831  [an Arizona State University, ASU, G.M., ASU P...
# 65832  [Smart Servier Medical Art., CC BY 3.0, the Ge...
# 65833  [T.S.-B., the University of Muenster Medical S...
#
#                                            NER_Flair_org
# 0      [Science Foundation Ireland, APC Microbiome Ir...
# 1                                                     NA
# 2                        [Dr. Pfleger Arzneimittel GmbH]
# 3      [Institute of Leisure Agriculture, Genepioneer...
# 4              [National Research Foundation, NRF, MSIT]
# ...                                                  ...
# 65829                      [Penn State Cancer Institute]
# 65830                                                 NA
# 65831       [., Arizona State University, ASU, ASU, NIH]
# 65832  [Smart Servier Medical Art, German Research Fo...
# 65833  [University of Muenster Medical School, Open A...
#
# [65834 rows x 12 columns]

# %%
NER_spacy_sm_org_match = []
for pmcid, orga_list in zip(ner_data['PMC_ID'], ner_data['NER_spacy_sm_org']):
    # print(pmcid,orga_list)
    temp = []
    for orga in orga_list:
        orga = orga.lower()
        if orga[0] in orga_dict.keys() and orga in orga_dict[orga[0]]:
            temp.append(orga)
    NER_spacy_sm_org_match.append(temp)

# %%
NER_spacy_md_org_match = []
for pmcid, orga_list in zip(ner_data['PMC_ID'], ner_data['NER_spacy_sm_org']):
    # print(pmcid,orga_list)
    temp = []
    for orga in orga_list:
        orga = orga.lower()
        if orga[0] in orga_dict.keys() and orga in orga_dict[orga[0]]:
            temp.append(orga)
    NER_spacy_md_org_match.append(temp)

# %%
NER_spacy_lg_org_match = []
for pmcid, orga_list in zip(ner_data['PMC_ID'], ner_data['NER_spacy_sm_org']):
    # print(pmcid,orga_list)
    temp = []
    for orga in orga_list:
        orga = orga.lower()
        if orga[0] in orga_dict.keys() and orga in orga_dict[orga[0]]:
            temp.append(orga)
    NER_spacy_lg_org_match.append(temp)

# %%
NER_Flair_org_match = []
for pmcid, orga_list in zip(ner_data['PMC_ID'], ner_data['NER_spacy_sm_org']):
    # print(pmcid,orga_list)
    temp = []
    for orga in orga_list:
        orga = orga.lower()
        if orga[0] in orga_dict.keys() and orga in orga_dict[orga[0]]:
            temp.append(orga)
    NER_Flair_org_match.append(temp)

# %% [markdown]
# **Creating a DataFrame**

# %%
NER_spacy_sm_org_match_df = pd.DataFrame(zip(ner_data['PMC_ID'],
                                            ner_data['acknowledgement'],
                                            NER_spacy_sm_org_match),
                                        columns = ['PMC_ID', 'Acknowledgement', 'Matched_Organizations'])
NER_spacy_md_org_match_df = pd.DataFrame(zip(ner_data['PMC_ID'],
                                            ner_data['acknowledgement'],
                                            NER_spacy_md_org_match),
                                        columns = ['PMC_ID', 'Acknowledgement', 'Matched_Organizations'])
NER_spacy_lg_org_match_df = pd.DataFrame(zip(ner_data['PMC_ID'],
                                            ner_data['acknowledgement'],
                                            NER_spacy_lg_org_match),
                                        columns = ['PMC_ID', 'Acknowledgement', 'Matched_Organizations'])
NER_Flair_org_match_df = pd.DataFrame(zip(ner_data['PMC_ID'],
                                            ner_data['acknowledgement'],
                                            NER_Flair_org_match),
                                        columns = ['PMC_ID', 'Acknowledgement', 'Matched_Organizations'])

# %% [markdown]
# **Saving the dataframe**

# %%
NER_spacy_sm_org_match_df.to_excel("matched_organiztion.xlsx", sheet_name = "NER_spacy_sm_org", index = False)
NER_spacy_md_org_match_df.to_excel("matched_organiztion.xlsx", sheet_name = "NER_spacy_md_org", index = False)
NER_spacy_lg_org_match_df.to_excel("matched_organiztion.xlsx", sheet_name = "NER_spacy_lg_org", index = False)
NER_Flair_org_match_df.to_excel("matched_organiztion.xlsx", sheet_name = "NER_Flair_org", index = False)

# %% [markdown]
# **II. Improved NER vs Crossref Baseline**
#
# Now we will sequentialy compare the results from the Crossref baseline model with those from improved versions of the NER tool output. The 4 Improved models for results from each NER tool are as follows -
#
# 1) NER_I - 'det_removal' function applied
#
# 2) NER_II - 'and_replacement' function applied
#
# 3) NER_III - 'punct_removal' function applied
#
# 4) NER_IV - 'det_removal' + 'and_replacement' + 'punct_removal' functions applied

# %%
result_match['Crossref baseline vs NER improved version I'] = {}
result_match['Crossref baseline vs NER improved version II'] = {}
result_match['Crossref baseline vs NER improved version III'] = {}
result_match['Crossref baseline vs NER improved version IV'] = {}

result_match_count['Crossref baseline vs NER improved version I'] = {}
result_match_count['Crossref baseline vs NER improved version II'] = {}
result_match_count['Crossref baseline vs NER improved version III'] = {}
result_match_count['Crossref baseline vs NER improved version IV'] = {}


#I
tool_output = {}
tool_names = ner_data.columns[-4:]
for tool in tool_names:
    NER_I = set([det_removal(case_lowering(ele))[0] for ele in text_processing(ner_data, tool) ])
    tool_output[tool] = NER_I
    match_count, match_result = result_matching(tool_output[tool],orga_dict)
    result_match_count['Crossref baseline vs NER improved version I'][tool] = int(len(tool_output[tool]))
    result_match_count['Crossref baseline vs NER improved version I'][tool+"_match"] = int(match_count)
    result_match_count['Crossref baseline vs NER improved version I'][tool+"_match_%"] = match_count*100/len(tool_output[tool])
    result_match['Crossref baseline vs NER improved version I'][tool] = match_result
    print("The match count between Crossref baseline model and " + tool + " improved version I :")
    print(match_count)
    
print("********************************************************************************************************")     
    
#II
tool_output = {}
tool_names = ner_data.columns[-4:]
for tool in tool_names:
    NER_II = set([and_replacement(case_lowering(ele)) for ele in text_processing(ner_data, tool)])
    tool_output[tool] = NER_II
    match_count, match_result = result_matching(tool_output[tool],orga_dict)
    result_match_count['Crossref baseline vs NER improved version II'][tool] = int(len(tool_output[tool]))
    result_match_count['Crossref baseline vs NER improved version II'][tool+"_match"] = int(match_count)
    result_match_count['Crossref baseline vs NER improved version II'][tool+"_match_%"] = match_count*100/len(tool_output[tool])
    result_match['Crossref baseline vs NER improved version II'][tool] = match_result
    print("The match count between Crossref baseline model and " + tool + " improved version II :")
    print(match_count)

print("********************************************************************************************************")     
    
#III
tool_output = {}
tool_names = ner_data.columns[-4:]
for tool in tool_names:
    NER_III = set([punct_removal(case_lowering(ele)) for ele in text_processing(ner_data, tool)])
    tool_output[tool] = NER_III
    match_count, match_result = result_matching(tool_output[tool],orga_dict)
    result_match_count['Crossref baseline vs NER improved version III'][tool] = int(len(tool_output[tool]))
    result_match_count['Crossref baseline vs NER improved version III'][tool+"_match"] = int(match_count)
    result_match_count['Crossref baseline vs NER improved version III'][tool+"_match_%"] = match_count*100/len(tool_output[tool])
    result_match['Crossref baseline vs NER improved version III'][tool] = match_result
    print("The match count between Crossref baseline model and " + tool + " improved version III :")
    print(match_count)

print("********************************************************************************************************")    
    
#IV
tool_output = {}
tool_names = ner_data.columns[-4:]
for tool in tool_names:
    NER_IV = set([punct_removal(and_replacement(det_removal(case_lowering(ele))[0])) for ele in text_processing(ner_data, tool)])
    tool_output[tool] = NER_IV
    match_count, match_result = result_matching(tool_output[tool],orga_dict)
    result_match_count['Crossref baseline vs NER improved version IV'][tool] = int(len(tool_output[tool]))
    result_match_count['Crossref baseline vs NER improved version IV'][tool+"_match"] = int(match_count)
    result_match_count['Crossref baseline vs NER improved version IV'][tool+"_match_%"] = match_count*100/len(tool_output[tool])
    result_match['Crossref baseline vs NER improved version IV'][tool] = match_result
    print("The match count between Crossref baseline model and " + tool + " improved version IV :")
    print(match_count)
# Out:
# The match count between Crossref baseline model and NER_spacy_sm_org improved version I :
# 9294
# The match count between Crossref baseline model and NER_spacy_md_org improved version I :
# 9522
# The match count between Crossref baseline model and NER_spacy_lg_org improved version I :
# 9544
# The match count between Crossref baseline model and NER_Flair_org improved version I :
# 11609
# ********************************************************************************************************
# The match count between Crossref baseline model and NER_spacy_sm_org improved version II :
# 7348
# The match count between Crossref baseline model and NER_spacy_md_org improved version II :
# 7584
# The match count between Crossref baseline model and NER_spacy_lg_org improved version II :
# 7611
# The match count between Crossref baseline model and NER_Flair_org improved version II :
# 10882
# ********************************************************************************************************
# The match count between Crossref baseline model and NER_spacy_sm_org improved version III :
# 7811
# The match count between Crossref baseline model and NER_spacy_md_org improved version III :
# 8057
# The match count between Crossref baseline model and NER_spacy_lg_org improved version III :
# 8064
# The match count between Crossref baseline model and NER_Flair_org improved version III :
# 11590
# ********************************************************************************************************
# The match count between Crossref baseline model and NER_spacy_sm_org improved version IV :
# 8643
# The match count between Crossref baseline model and NER_spacy_md_org improved version IV :
# 8809
# The match count between Crossref baseline model and NER_spacy_lg_org improved version IV :
# 8805
# The match count between Crossref baseline model and NER_Flair_org improved version IV :
# 10741

# %%
result_df.loc['Crossref baseline vs NER improved version I'] = pd.Series(result_match_count['Crossref baseline vs NER improved version I'])
result_df.loc['Crossref baseline vs NER improved version II'] = pd.Series(result_match_count['Crossref baseline vs NER improved version II'])
result_df.loc['Crossref baseline vs NER improved version III'] = pd.Series(result_match_count['Crossref baseline vs NER improved version III'])
result_df.loc['Crossref baseline vs NER improved version IV'] = pd.Series(result_match_count['Crossref baseline vs NER improved version IV'])

# %%
result_df
# Out:
#                                                    NER_spacy_sm_org  \
# Crossref baseline vs NER baseline                           97859.0
# Crossref baseline vs NER improved version I                 92970.0
# Crossref baseline vs NER improved version II                97688.0
# Crossref baseline vs NER improved version III               96143.0
# Crossref baseline vs NER improved version IV                91058.0
# NER baseline vs Crossref improved version I                     NaN
# NER baseline vs Crossref improved version II                    NaN
# NER baseline vs Crossref improved version III                   NaN
# NER baseline vs Crossref improved version IV                    NaN
# NER improved version I vs Crossref improved ver...              NaN
# NER improved version II vs Crossref improved ve...              NaN
# NER improved version III vs Crossref improved v...              NaN
# NER improved version IV vs Crossref improved ve...              NaN
#
#                                                    NER_spacy_sm_org_match  \
# Crossref baseline vs NER baseline                                  7762.0
# Crossref baseline vs NER improved version I                        9294.0
# Crossref baseline vs NER improved version II                       7348.0
# Crossref baseline vs NER improved version III                      7811.0
# Crossref baseline vs NER improved version IV                       8643.0
# NER baseline vs Crossref improved version I                           NaN
# NER baseline vs Crossref improved version II                          NaN
# NER baseline vs Crossref improved version III                         NaN
# NER baseline vs Crossref improved version IV                          NaN
# NER improved version I vs Crossref improved ver...                    NaN
# NER improved version II vs Crossref improved ve...                    NaN
# NER improved version III vs Crossref improved v...                    NaN
# NER improved version IV vs Crossref improved ve...                    NaN
#
#                                                    NER_spacy_sm_org_match_%  \
# Crossref baseline vs NER baseline                                   7.93182
# Crossref baseline vs NER improved version I                        9.996773
# Crossref baseline vs NER improved version II                       7.521906
# Crossref baseline vs NER improved version III                      8.124356
# Crossref baseline vs NER improved version IV                       9.491753
# NER baseline vs Crossref improved version I                             NaN
# NER baseline vs Crossref improved version II                            NaN
# NER baseline vs Crossref improved version III                           NaN
# NER baseline vs Crossref improved version IV                            NaN
# NER improved version I vs Crossref improved ver...                      NaN
# NER improved version II vs Crossref improved ve...                      NaN
# NER improved version III vs Crossref improved v...                      NaN
# NER improved version IV vs Crossref improved ve...                      NaN
#
#                                                    NER_spacy_md_org  \
# Crossref baseline vs NER baseline                          102144.0
# Crossref baseline vs NER improved version I                 96974.0
# Crossref baseline vs NER improved version II               101971.0
# Crossref baseline vs NER improved version III              100323.0
# Crossref baseline vs NER improved version IV                94958.0
# NER baseline vs Crossref improved version I                     NaN
# NER baseline vs Crossref improved version II                    NaN
# NER baseline vs Crossref improved version III                   NaN
# NER baseline vs Crossref improved version IV                    NaN
# NER improved version I vs Crossref improved ver...              NaN
# NER improved version II vs Crossref improved ve...              NaN
# NER improved version III vs Crossref improved v...              NaN
# NER improved version IV vs Crossref improved ve...              NaN
#
#                                                    NER_spacy_md_org_match  \
# Crossref baseline vs NER baseline                                  8045.0
# Crossref baseline vs NER improved version I                        9522.0
# Crossref baseline vs NER improved version II                       7584.0
# Crossref baseline vs NER improved version III                      8057.0
# Crossref baseline vs NER improved version IV                       8809.0
# NER baseline vs Crossref improved version I                           NaN
# NER baseline vs Crossref improved version II                          NaN
# NER baseline vs Crossref improved version III                         NaN
# NER baseline vs Crossref improved version IV                          NaN
# NER improved version I vs Crossref improved ver...                    NaN
# NER improved version II vs Crossref improved ve...                    NaN
# NER improved version III vs Crossref improved v...                    NaN
# NER improved version IV vs Crossref improved ve...                    NaN
#
#                                                    NER_spacy_md_org_match_%  \
# Crossref baseline vs NER baseline                                  7.876136
# Crossref baseline vs NER improved version I                        9.819127
# Crossref baseline vs NER improved version II                       7.437409
# Crossref baseline vs NER improved version III                       8.03106
# Crossref baseline vs NER improved version IV                       9.276733
# NER baseline vs Crossref improved version I                             NaN
# NER baseline vs Crossref improved version II                            NaN
# NER baseline vs Crossref improved version III                           NaN
# NER baseline vs Crossref improved version IV                            NaN
# NER improved version I vs Crossref improved ver...                      NaN
# NER improved version II vs Crossref improved ve...                      NaN
# NER improved version III vs Crossref improved v...                      NaN
# NER improved version IV vs Crossref improved ve...                      NaN
#
#                                                    NER_spacy_lg_org  \
# Crossref baseline vs NER baseline                          101777.0
# Crossref baseline vs NER improved version I                 96723.0
# Crossref baseline vs NER improved version II               101618.0
# Crossref baseline vs NER improved version III               99956.0
# Crossref baseline vs NER improved version IV                94712.0
# NER baseline vs Crossref improved version I                     NaN
# NER baseline vs Crossref improved version II                    NaN
# NER baseline vs Crossref improved version III                   NaN
# NER baseline vs Crossref improved version IV                    NaN
# NER improved version I vs Crossref improved ver...              NaN
# NER improved version II vs Crossref improved ve...              NaN
# NER improved version III vs Crossref improved v...              NaN
# NER improved version IV vs Crossref improved ve...              NaN
#
#                                                    NER_spacy_lg_org_match  \
# Crossref baseline vs NER baseline                                  8071.0
# Crossref baseline vs NER improved version I                        9544.0
# Crossref baseline vs NER improved version II                       7611.0
# Crossref baseline vs NER improved version III                      8064.0
# Crossref baseline vs NER improved version IV                       8805.0
# NER baseline vs Crossref improved version I                           NaN
# NER baseline vs Crossref improved version II                          NaN
# NER baseline vs Crossref improved version III                         NaN
# NER baseline vs Crossref improved version IV                          NaN
# NER improved version I vs Crossref improved ver...                    NaN
# NER improved version II vs Crossref improved ve...                    NaN
# NER improved version III vs Crossref improved v...                    NaN
# NER improved version IV vs Crossref improved ve...                    NaN
#
#                                                    NER_spacy_lg_org_match_%  \
# Crossref baseline vs NER baseline                                  7.930082
# Crossref baseline vs NER improved version I                        9.867353
# Crossref baseline vs NER improved version II                       7.489815
# Crossref baseline vs NER improved version III                       8.06755
# Crossref baseline vs NER improved version IV                       9.296604
# NER baseline vs Crossref improved version I                             NaN
# NER baseline vs Crossref improved version II                            NaN
# NER baseline vs Crossref improved version III                           NaN
# NER baseline vs Crossref improved version IV                            NaN
# NER improved version I vs Crossref improved ver...                      NaN
# NER improved version II vs Crossref improved ve...                      NaN
# NER improved version III vs Crossref improved v...                      NaN
# NER improved version IV vs Crossref improved ve...                      NaN
#
#                                                    NER_Flair_org  \
# Crossref baseline vs NER baseline                        75465.0
# Crossref baseline vs NER improved version I              74910.0
# Crossref baseline vs NER improved version II             75256.0
# Crossref baseline vs NER improved version III            73372.0
# Crossref baseline vs NER improved version IV             72601.0
# NER baseline vs Crossref improved version I                  NaN
# NER baseline vs Crossref improved version II                 NaN
# NER baseline vs Crossref improved version III                NaN
# NER baseline vs Crossref improved version IV                 NaN
# NER improved version I vs Crossref improved ver...           NaN
# NER improved version II vs Crossref improved ve...           NaN
# NER improved version III vs Crossref improved v...           NaN
# NER improved version IV vs Crossref improved ve...           NaN
#
#                                                    NER_Flair_org_match  \
# Crossref baseline vs NER baseline                              11682.0
# Crossref baseline vs NER improved version I                    11609.0
# Crossref baseline vs NER improved version II                   10882.0
# Crossref baseline vs NER improved version III                  11590.0
# Crossref baseline vs NER improved version IV                   10741.0
# NER baseline vs Crossref improved version I                        NaN
# NER baseline vs Crossref improved version II                       NaN
# NER baseline vs Crossref improved version III                      NaN
# NER baseline vs Crossref improved version IV                       NaN
# NER improved version I vs Crossref improved ver...                 NaN
# NER improved version II vs Crossref improved ve...                 NaN
# NER improved version III vs Crossref improved v...                 NaN
# NER improved version IV vs Crossref improved ve...                 NaN
#
#                                                    NER_Flair_org_match_%
# Crossref baseline vs NER baseline                              15.480024
# Crossref baseline vs NER improved version I                    15.497263
# Crossref baseline vs NER improved version II                   14.459977
# Crossref baseline vs NER improved version III                  15.796217
# Crossref baseline vs NER improved version IV                   14.794562
# NER baseline vs Crossref improved version I                          NaN
# NER baseline vs Crossref improved version II                         NaN
# NER baseline vs Crossref improved version III                        NaN
# NER baseline vs Crossref improved version IV                         NaN
# NER improved version I vs Crossref improved ver...                   NaN
# NER improved version II vs Crossref improved ve...                   NaN
# NER improved version III vs Crossref improved v...                   NaN
# NER improved version IV vs Crossref improved ve...                   NaN

# %% [markdown]
# **Applying the preprocessing function to orga_dict**
#
# Now we will sequentially apply all the preprocessing functions to 'orga_dict' containing organization names from the Crossref Funder Registry. The 4 variations to the orga_dict as as follows -
#
#
# 1) orga_dict_I - 'det_removal' function applied
#
# 2) orga_dict_I - 'and_replacement' function applied
#
# 3) orga_dict_I - 'punct_removal' function applied
#
# 4) orga_dict_I - 'det_removal' + 'and_replacement' + 'punct_removal' functions applied

# %%
from collections import defaultdict

orga_dict_I = {}
orga_dict_II = {}
orga_dict_III = {}
orga_dict_IV = {}


for ele in orga_dict:
    for i in range(len(orga_dict[ele])):
        new_key = det_removal(orga_dict[ele][i])
        new_key = new_key[1]
        if new_key not in orga_dict_I:
            orga_dict_I[new_key] = [det_removal(orga_dict[ele][i])[0]]
        else:   
            orga_dict_I[new_key].append(det_removal(orga_dict[ele][i])[0])
        
        if ele not in orga_dict_II:
            orga_dict_II[ele] = [and_replacement(orga_dict[ele][i])]
        else:
            orga_dict_II[ele].append(and_replacement(orga_dict[ele][i]))                               
        
        if ele not in orga_dict_III:
            orga_dict_III[ele] = [punct_removal(orga_dict[ele][i])]                            
        else:
            orga_dict_III[ele].append(punct_removal(orga_dict[ele][i]))
        
        if new_key not in orga_dict_IV:
            orga_dict_IV[new_key] = [punct_removal(and_replacement(det_removal(orga_dict[ele][i])[0]))]
        else:
            orga_dict_IV[new_key].append(punct_removal(and_replacement(det_removal(orga_dict[ele][i])[0])))

# %% [markdown]
# **III. NER Baseline vs Improved Crossref**
#
# Now we will sequentialy compare the results from the NER baseline model with those from improved versions of Crossref output.

# %%
result_match['NER baseline vs Crossref improved version I'] = {}
result_match['NER baseline vs Crossref improved version II'] = {}
result_match['NER baseline vs Crossref improved version III'] = {}
result_match['NER baseline vs Crossref improved version IV'] = {}

result_match_count['NER baseline vs Crossref improved version I'] = {}
result_match_count['NER baseline vs Crossref improved version II'] = {}
result_match_count['NER baseline vs Crossref improved version III'] = {}
result_match_count['NER baseline vs Crossref improved version IV'] = {}




#I
tool_output = {}
tool_names = ner_data.columns[-4:]
for tool in tool_names:
    tool_output[tool] = set([case_lowering(ele) for ele in text_processing(ner_data, tool)])
    match_count, match_result = result_matching(tool_output[tool],orga_dict_I)
    result_match_count['NER baseline vs Crossref improved version I'][tool] = int(len(tool_output[tool]))
    result_match_count['NER baseline vs Crossref improved version I'][tool+"_match"] = int(match_count)
    result_match_count['NER baseline vs Crossref improved version I'][tool+"_match_%"] = match_count*100/len(tool_output[tool])
    result_match['NER baseline vs Crossref improved version I'][tool] = match_result
    print("The match count between" + tool +  "baseline model and Crossref improved version I :")
    print(match_count)
    
print("********************************************************************************************************")

#II
tool_output = {}
tool_names = ner_data.columns[-4:]
for tool in tool_names:
    tool_output[tool] = set([case_lowering(ele) for ele in text_processing(ner_data, tool)])
    match_count, match_result = result_matching(tool_output[tool],orga_dict_II)
    result_match_count['NER baseline vs Crossref improved version II'][tool] = int(len(tool_output[tool]))
    result_match_count['NER baseline vs Crossref improved version II'][tool+"_match"] = int(match_count)
    result_match_count['NER baseline vs Crossref improved version II'][tool+"_match_%"] = match_count*100/len(tool_output[tool])
    result_match['NER baseline vs Crossref improved version II'][tool] = match_result
    print("The match count between" + tool +  "baseline model and Crossref improved version II :")
    print(match_count)
    
print("********************************************************************************************************")

#III
tool_output = {}
tool_names = ner_data.columns[-4:]
for tool in tool_names:
    tool_output[tool] = set([case_lowering(ele) for ele in text_processing(ner_data, tool)])
    match_count, match_result = result_matching(tool_output[tool],orga_dict_III)
    result_match_count['NER baseline vs Crossref improved version III'][tool] = int(len(tool_output[tool]))
    result_match_count['NER baseline vs Crossref improved version III'][tool+"_match"] = int(match_count)
    result_match_count['NER baseline vs Crossref improved version III'][tool+"_match_%"] = match_count*100/len(tool_output[tool])
    result_match['NER baseline vs Crossref improved version III'][tool] = match_result
    print("The match count between" + tool +  "baseline model and Crossref improved version III :")
    print(match_count)
    
print("********************************************************************************************************")

#IV
tool_output = {}
tool_names = ner_data.columns[-4:]
for tool in tool_names:
    tool_output[tool] = set([case_lowering(ele) for ele in text_processing(ner_data, tool)])
    match_count, match_result = result_matching(tool_output[tool],orga_dict_IV)
    result_match_count['NER baseline vs Crossref improved version IV'][tool] = int(len(tool_output[tool]))
    result_match_count['NER baseline vs Crossref improved version IV'][tool+"_match"] = int(match_count)
    result_match_count['NER baseline vs Crossref improved version IV'][tool+"_match_%"] = match_count*100/len(tool_output[tool])
    result_match['NER baseline vs Crossref improved version IV'][tool] = match_result
    print("The match count between" + tool +  "baseline model and Crossref improved version IV :")
    print(match_count)
# Out:
# The match count betweenNER_spacy_sm_orgbaseline model and Crossref improved version I :
# 7244
# The match count betweenNER_spacy_md_orgbaseline model and Crossref improved version I :
# 7522
# The match count betweenNER_spacy_lg_orgbaseline model and Crossref improved version I :
# 7536
# The match count betweenNER_Flair_orgbaseline model and Crossref improved version I :
# 11584
# ********************************************************************************************************
# The match count betweenNER_spacy_sm_orgbaseline model and Crossref improved version II :
# 7309
# The match count betweenNER_spacy_md_orgbaseline model and Crossref improved version II :
# 7533
# The match count betweenNER_spacy_lg_orgbaseline model and Crossref improved version II :
# 7558
# The match count betweenNER_Flair_orgbaseline model and Crossref improved version II :
# 10757
# ********************************************************************************************************
# The match count betweenNER_spacy_sm_orgbaseline model and Crossref improved version III :
# 7516
# The match count betweenNER_spacy_md_orgbaseline model and Crossref improved version III :
# 7756
# The match count betweenNER_spacy_lg_orgbaseline model and Crossref improved version III :
# 7767
# The match count betweenNER_Flair_orgbaseline model and Crossref improved version III :
# 11426
# ********************************************************************************************************
# The match count betweenNER_spacy_sm_orgbaseline model and Crossref improved version IV :
# 6611
# The match count betweenNER_spacy_md_orgbaseline model and Crossref improved version IV :
# 6798
# The match count betweenNER_spacy_lg_orgbaseline model and Crossref improved version IV :
# 6799
# The match count betweenNER_Flair_orgbaseline model and Crossref improved version IV :
# 10418

# %%
result_df.loc['NER baseline vs Crossref improved version I'] = pd.Series(result_match_count['NER baseline vs Crossref improved version I'])
result_df.loc['NER baseline vs Crossref improved version II'] = pd.Series(result_match_count['NER baseline vs Crossref improved version II'])
result_df.loc['NER baseline vs Crossref improved version III'] = pd.Series(result_match_count['NER baseline vs Crossref improved version III'])
result_df.loc['NER baseline vs Crossref improved version IV'] = pd.Series(result_match_count['NER baseline vs Crossref improved version IV'])

# %%
result_df
# Out:
#                                                    NER_spacy_sm_org  \
# Crossref baseline vs NER baseline                           97859.0
# Crossref baseline vs NER improved version I                 92970.0
# Crossref baseline vs NER improved version II                97688.0
# Crossref baseline vs NER improved version III               96143.0
# Crossref baseline vs NER improved version IV                91058.0
# NER baseline vs Crossref improved version I                 97859.0
# NER baseline vs Crossref improved version II                97859.0
# NER baseline vs Crossref improved version III               97859.0
# NER baseline vs Crossref improved version IV                97859.0
# NER improved version I vs Crossref improved ver...              NaN
# NER improved version II vs Crossref improved ve...              NaN
# NER improved version III vs Crossref improved v...              NaN
# NER improved version IV vs Crossref improved ve...              NaN
#
#                                                    NER_spacy_sm_org_match  \
# Crossref baseline vs NER baseline                                  7762.0
# Crossref baseline vs NER improved version I                        9294.0
# Crossref baseline vs NER improved version II                       7348.0
# Crossref baseline vs NER improved version III                      7811.0
# Crossref baseline vs NER improved version IV                       8643.0
# NER baseline vs Crossref improved version I                        7244.0
# NER baseline vs Crossref improved version II                       7309.0
# NER baseline vs Crossref improved version III                      7516.0
# NER baseline vs Crossref improved version IV                       6611.0
# NER improved version I vs Crossref improved ver...                    NaN
# NER improved version II vs Crossref improved ve...                    NaN
# NER improved version III vs Crossref improved v...                    NaN
# NER improved version IV vs Crossref improved ve...                    NaN
#
#                                                    NER_spacy_sm_org_match_%  \
# Crossref baseline vs NER baseline                                   7.93182
# Crossref baseline vs NER improved version I                        9.996773
# Crossref baseline vs NER improved version II                       7.521906
# Crossref baseline vs NER improved version III                      8.124356
# Crossref baseline vs NER improved version IV                       9.491753
# NER baseline vs Crossref improved version I                        7.402487
# NER baseline vs Crossref improved version II                       7.468909
# NER baseline vs Crossref improved version III                      7.680438
# NER baseline vs Crossref improved version IV                       6.755638
# NER improved version I vs Crossref improved ver...                      NaN
# NER improved version II vs Crossref improved ve...                      NaN
# NER improved version III vs Crossref improved v...                      NaN
# NER improved version IV vs Crossref improved ve...                      NaN
#
#                                                    NER_spacy_md_org  \
# Crossref baseline vs NER baseline                          102144.0
# Crossref baseline vs NER improved version I                 96974.0
# Crossref baseline vs NER improved version II               101971.0
# Crossref baseline vs NER improved version III              100323.0
# Crossref baseline vs NER improved version IV                94958.0
# NER baseline vs Crossref improved version I                102144.0
# NER baseline vs Crossref improved version II               102144.0
# NER baseline vs Crossref improved version III              102144.0
# NER baseline vs Crossref improved version IV               102144.0
# NER improved version I vs Crossref improved ver...              NaN
# NER improved version II vs Crossref improved ve...              NaN
# NER improved version III vs Crossref improved v...              NaN
# NER improved version IV vs Crossref improved ve...              NaN
#
#                                                    NER_spacy_md_org_match  \
# Crossref baseline vs NER baseline                                  8045.0
# Crossref baseline vs NER improved version I                        9522.0
# Crossref baseline vs NER improved version II                       7584.0
# Crossref baseline vs NER improved version III                      8057.0
# Crossref baseline vs NER improved version IV                       8809.0
# NER baseline vs Crossref improved version I                        7522.0
# NER baseline vs Crossref improved version II                       7533.0
# NER baseline vs Crossref improved version III                      7756.0
# NER baseline vs Crossref improved version IV                       6798.0
# NER improved version I vs Crossref improved ver...                    NaN
# NER improved version II vs Crossref improved ve...                    NaN
# NER improved version III vs Crossref improved v...                    NaN
# NER improved version IV vs Crossref improved ve...                    NaN
#
#                                                    NER_spacy_md_org_match_%  \
# Crossref baseline vs NER baseline                                  7.876136
# Crossref baseline vs NER improved version I                        9.819127
# Crossref baseline vs NER improved version II                       7.437409
# Crossref baseline vs NER improved version III                       8.03106
# Crossref baseline vs NER improved version IV                       9.276733
# NER baseline vs Crossref improved version I                        7.364113
# NER baseline vs Crossref improved version II                       7.374883
# NER baseline vs Crossref improved version III                      7.593202
# NER baseline vs Crossref improved version IV                        6.65531
# NER improved version I vs Crossref improved ver...                      NaN
# NER improved version II vs Crossref improved ve...                      NaN
# NER improved version III vs Crossref improved v...                      NaN
# NER improved version IV vs Crossref improved ve...                      NaN
#
#                                                    NER_spacy_lg_org  \
# Crossref baseline vs NER baseline                          101777.0
# Crossref baseline vs NER improved version I                 96723.0
# Crossref baseline vs NER improved version II               101618.0
# Crossref baseline vs NER improved version III               99956.0
# Crossref baseline vs NER improved version IV                94712.0
# NER baseline vs Crossref improved version I                101777.0
# NER baseline vs Crossref improved version II               101777.0
# NER baseline vs Crossref improved version III              101777.0
# NER baseline vs Crossref improved version IV               101777.0
# NER improved version I vs Crossref improved ver...              NaN
# NER improved version II vs Crossref improved ve...              NaN
# NER improved version III vs Crossref improved v...              NaN
# NER improved version IV vs Crossref improved ve...              NaN
#
#                                                    NER_spacy_lg_org_match  \
# Crossref baseline vs NER baseline                                  8071.0
# Crossref baseline vs NER improved version I                        9544.0
# Crossref baseline vs NER improved version II                       7611.0
# Crossref baseline vs NER improved version III                      8064.0
# Crossref baseline vs NER improved version IV                       8805.0
# NER baseline vs Crossref improved version I                        7536.0
# NER baseline vs Crossref improved version II                       7558.0
# NER baseline vs Crossref improved version III                      7767.0
# NER baseline vs Crossref improved version IV                       6799.0
# NER improved version I vs Crossref improved ver...                    NaN
# NER improved version II vs Crossref improved ve...                    NaN
# NER improved version III vs Crossref improved v...                    NaN
# NER improved version IV vs Crossref improved ve...                    NaN
#
#                                                    NER_spacy_lg_org_match_%  \
# Crossref baseline vs NER baseline                                  7.930082
# Crossref baseline vs NER improved version I                        9.867353
# Crossref baseline vs NER improved version II                       7.489815
# Crossref baseline vs NER improved version III                       8.06755
# Crossref baseline vs NER improved version IV                       9.296604
# NER baseline vs Crossref improved version I                        7.404423
# NER baseline vs Crossref improved version II                       7.426039
# NER baseline vs Crossref improved version III                       7.63139
# NER baseline vs Crossref improved version IV                       6.680291
# NER improved version I vs Crossref improved ver...                      NaN
# NER improved version II vs Crossref improved ve...                      NaN
# NER improved version III vs Crossref improved v...                      NaN
# NER improved version IV vs Crossref improved ve...                      NaN
#
#                                                    NER_Flair_org  \
# Crossref baseline vs NER baseline                        75465.0
# Crossref baseline vs NER improved version I              74910.0
# Crossref baseline vs NER improved version II             75256.0
# Crossref baseline vs NER improved version III            73372.0
# Crossref baseline vs NER improved version IV             72601.0
# NER baseline vs Crossref improved version I              75465.0
# NER baseline vs Crossref improved version II             75465.0
# NER baseline vs Crossref improved version III            75465.0
# NER baseline vs Crossref improved version IV             75465.0
# NER improved version I vs Crossref improved ver...           NaN
# NER improved version II vs Crossref improved ve...           NaN
# NER improved version III vs Crossref improved v...           NaN
# NER improved version IV vs Crossref improved ve...           NaN
#
#                                                    NER_Flair_org_match  \
# Crossref baseline vs NER baseline                              11682.0
# Crossref baseline vs NER improved version I                    11609.0
# Crossref baseline vs NER improved version II                   10882.0
# Crossref baseline vs NER improved version III                  11590.0
# Crossref baseline vs NER improved version IV                   10741.0
# NER baseline vs Crossref improved version I                    11584.0
# NER baseline vs Crossref improved version II                   10757.0
# NER baseline vs Crossref improved version III                  11426.0
# NER baseline vs Crossref improved version IV                   10418.0
# NER improved version I vs Crossref improved ver...                 NaN
# NER improved version II vs Crossref improved ve...                 NaN
# NER improved version III vs Crossref improved v...                 NaN
# NER improved version IV vs Crossref improved ve...                 NaN
#
#                                                    NER_Flair_org_match_%
# Crossref baseline vs NER baseline                              15.480024
# Crossref baseline vs NER improved version I                    15.497263
# Crossref baseline vs NER improved version II                   14.459977
# Crossref baseline vs NER improved version III                  15.796217
# Crossref baseline vs NER improved version IV                   14.794562
# NER baseline vs Crossref improved version I                    15.350162
# NER baseline vs Crossref improved version II                    14.25429
# NER baseline vs Crossref improved version III                  15.140794
# NER baseline vs Crossref improved version IV                   13.805075
# NER improved version I vs Crossref improved ver...                   NaN
# NER improved version II vs Crossref improved ve...                   NaN
# NER improved version III vs Crossref improved v...                   NaN
# NER improved version IV vs Crossref improved ve...                   NaN

# %% [markdown]
# **IV. Improved NER vs Improved Crossref**
#
# Finally we will sequentially compare the results of Improved Crossref with Improved NER models

# %%
result_match['NER improved version I vs Crossref improved version I'] = {}
result_match['NER improved version II vs Crossref improved version II'] = {}
result_match['NER improved version III vs Crossref improved version III'] = {}
result_match['NER improved version IV vs Crossref improved version IV'] = {}

result_match_count['NER improved version I vs Crossref improved version I'] = {}
result_match_count['NER improved version II vs Crossref improved version II'] = {}
result_match_count['NER improved version III vs Crossref improved version III'] = {}
result_match_count['NER improved version IV vs Crossref improved version IV'] = {}



#I
tool_output = {}
tool_names = ner_data.columns[-4:]
for tool in tool_names:
    tool_output[tool] = set([det_removal(case_lowering(ele))[0] for ele in text_processing(ner_data, tool)])
    match_count, match_result = result_matching(tool_output[tool],orga_dict_I)
    result_match_count['NER improved version I vs Crossref improved version I'][tool] = int(len(tool_output[tool]))
    result_match_count['NER improved version I vs Crossref improved version I'][tool+"_match"] = int(match_count)
    result_match_count['NER improved version I vs Crossref improved version I'][tool+"_match_%"] = match_count*100/len(tool_output[tool])
    result_match['NER improved version I vs Crossref improved version I'][tool] = match_result
    print("The match count between" + tool +  "improved version I and Crossref improved version I :")
    print(match_count)
    print(match_result)
    
print("********************************************************************************************************")
    
#II
tool_output = {}
tool_names = ner_data.columns[-4:]
for tool in tool_names:
    tool_output[tool] = set([and_replacement(case_lowering(ele)) for ele in text_processing(ner_data, tool)])
    match_count, match_result = result_matching(tool_output[tool],orga_dict_II)
    result_match_count['NER improved version II vs Crossref improved version II'][tool] = int(len(tool_output[tool]))
    result_match_count['NER improved version II vs Crossref improved version II'][tool+"_match"] = int(match_count)
    result_match_count['NER improved version II vs Crossref improved version II'][tool+"_match_%"] = match_count*100/len(tool_output[tool])
    result_match['NER improved version II vs Crossref improved version II'][tool] = match_result
    print("The match count between" + tool +  "improved version II and Crossref improved version II :")
    print(match_count)
    print(match_result)
    
print("********************************************************************************************************")    

#III
tool_output = {}
tool_names = ner_data.columns[-4:]
for tool in tool_names:
    tool_output[tool] = set([punct_removal(case_lowering(ele)) for ele in text_processing(ner_data, tool)])
    match_count, match_result = result_matching(tool_output[tool],orga_dict_III)
    result_match_count['NER improved version III vs Crossref improved version III'][tool] = int(len(tool_output[tool]))
    result_match_count['NER improved version III vs Crossref improved version III'][tool+"_match"] = int(match_count)
    result_match_count['NER improved version III vs Crossref improved version III'][tool+"_match_%"] = match_count*100/len(tool_output[tool])
    result_match['NER improved version III vs Crossref improved version III'][tool] = match_result
    print("The match count between" + tool +  "improved version III and Crossref improved version III :")
    print(match_count)
    print(match_result)
    
print("********************************************************************************************************")    

#IV
tool_output = {}
tool_names = ner_data.columns[-4:]
for tool in tool_names:
    tool_output[tool] = set([punct_removal(and_replacement(det_removal(case_lowering(ele))[0])) for ele in text_processing(ner_data, tool)])
    match_count, match_result = result_matching(tool_output[tool],orga_dict_IV)
    result_match_count['NER improved version IV vs Crossref improved version IV'][tool] = int(len(tool_output[tool]))
    result_match_count['NER improved version IV vs Crossref improved version IV'][tool+"_match"] = int(match_count)
    result_match_count['NER improved version IV vs Crossref improved version IV'][tool+"_match_%"] = match_count*100/len(tool_output[tool])
    result_match['NER improved version IV vs Crossref improved version IV'][tool] = match_result
    print("The match count between" + tool +  "improved version IV and Crossref improved version IV :")
    print(match_count)
    print(match_result)
# Out:
# The match count betweenNER_spacy_sm_orgimproved version I and Crossref improved version I :
# 9337
# ['international tennis federation', 'national taiwan ocean university', 'global health', 'innovate uk', 'laqv', 'fmd', 'industrial technology research institute', 'hospital universiti sains malaysia', 'national council for scientific and technological development', 'royal institute of technology', 'autonomous university of chapingo', 'montreal general hospital foundation', 'australian genome research facility', 'society for maternal fetal medicine', 'dh', 'shanghai municipal health and family planning commission', 'tsgh', 'beth israel deaconess medical center', 'frc', 'beijing foreign studies university', 'astra', 'spa', 'agria pet insurance', 'lcm', 'university of dar es salaam', 'hlf', 'cai', 'diabetes australia', 'centre for cognitive ageing and cognitive epidemiology', 'aag', 'promotion and mutual aid corporation for private schools of japan', 'bialystok university of technology', 'hunan provincial science and technology plan project', 'national social science foundation', 'embrapa genetic resources and biotechnology', 'ubc', 'naval medical research center', 'petrus och augusta hedlunds stiftelse', 'john s. latsis public benefit foundation', 'national program for support of top-notch young professionals', 'wp', 'virbac', 'university of macedonia', 'southwest hospital', 'als association', 'food, agriculture and fisheries, biotechnology', 'lg chem ltd.', 'sweden-america foundation', 'lccc', 'thailand development research institute', 'thailand center of excellence for life sciences', 'darwin trust', 'vlir-uos', 'sic', 'institut de bioenginyeria de catalunya', 'kaul pediatric research institute', 'udec', 'business finland', 'ibm', 'bavarian state ministry for science and art', 'pb', 'college of agriculture and natural resources', 'monell chemical senses center', 'burroughs wellcome fund', 'u.s. army corps of engineers', 'shenzhen science and technology innovation commission', 'czech science foundation', 'autonomous community of the region of murcia', 'stfc', 'world academy of sciences', 'japan epilepsy research foundation', 'immunodeficiency canada', 'dae', 'korea international cooperation agency', 'pharmaceutical society of western australia', 'kyorin university school of medicine', 'u.s. national institute on aging', 'fs', 'ga', 'tsc', 'wenzhou science and technology bureau', 'italian medicines agency', 'vci', 'national institute of standards and technology', 'tms', 'cystic fibrosis foundation', 'horizon pharmaceuticals', 'korean society of nephrology', 'icmc', 'ohio university', 'china postdoctoral science foundation', 'itm', 'haryana state council for science and technology', 'canada research chairs', 'nih common fund', 'amsterdam umc', 'samara university', 'siriraj hospital', 'georgia institute of technology', 'ingham institute', 'fosu', 'northeast als consortium', 'ms research australia', 'msf', 'universidade de vigo', 'shanxi science and technology department', 'kleberg foundation', 'helsinki university central hospital', 'john innes foundation', 'ao', 'spanish ministry of science and technology', 'lingnan normal university', 'redissec', 'virginia commonwealth university', 'idaho state university', 'cancer center', 'university of duisburg-essen', 'nih national institute of environmental health sciences', 'sirf', 'sbs', 'u.s. air force', 'ups', 'japan science and technology corporation', 'cirmf', 'mbf', 'sichuan agricultural university', 'nih blueprint for neuroscience research', 'australian catholic university', 'kmitl', 'sontag foundation', 'australian housing and urban research institute', 'irish centre for high end computing', 'ccd', 'meta', 'national scientific and technical research council', 'small business innovation research', 'xuzhou medical university', 'china agricultural research system', 'infosys foundation', 'ud', 'american college of preventive medicine', 'american society for radiation oncology', 'adc', 'national space biomedical research institute', 'rheumasearch foundation', 'amsterdam university medic ...
# The match count betweenNER_spacy_md_orgimproved version I and Crossref improved version I :
# 9567
# ['international tennis federation', 'national taiwan ocean university', 'global health', 'innovate uk', 'laqv', 'industrial technology research institute', 'national council for scientific and technological development', 'royal institute of technology', 'autonomous university of chapingo', 'montreal general hospital foundation', 'australian genome research facility', 'society for maternal fetal medicine', 'dh', 'tsgh', 'beth israel deaconess medical center', 'frc', 'beijing foreign studies university', 'astra', 'spa', 'agria pet insurance', 'lcm', 'university of dar es salaam', 'schweizerische herzstiftung', 'hlf', 'cai', 'diabetes australia', 'sums', 'miller institute', 'promotion and mutual aid corporation for private schools of japan', 'bialystok university of technology', 'hunan provincial science and technology plan project', 'national social science foundation', 'embrapa genetic resources and biotechnology', 'ubc', 'naval medical research center', 'john s. latsis public benefit foundation', 'wuhan national biosafety laboratory', 'national program for support of top-notch young professionals', 'wp', 'virbac', 'a-step', 'university of macedonia', 'southwest hospital', 'arsla', 'als association', 'wcr', 'lg chem ltd.', 'sweden-america foundation', 'thailand development research institute', 'lccc', 'thailand center of excellence for life sciences', 'darwin trust', 'vlir-uos', 'institut de bioenginyeria de catalunya', 'kaul pediatric research institute', 'business finland', 'ibm', 'bavarian state ministry for science and art', 'pb', 'college of agriculture and natural resources', 'monell chemical senses center', 'burroughs wellcome fund', 'u.s. army corps of engineers', 'shenzhen science and technology innovation commission', 'czech science foundation', 'autonomous community of the region of murcia', 'stfc', 'world academy of sciences', 'united states department of energy', 'japan epilepsy research foundation', 'immunodeficiency canada', 'universidade federal de santa catarina', 'dae', 'korea international cooperation agency', 'pharmaceutical society of western australia', 'kyorin university school of medicine', 'u.s. national institute on aging', 'fs', 'ga', 'mest', 'tsc', 'wenzhou science and technology bureau', 'italian medicines agency', 'vci', 'national institute of standards and technology', 'tms', 'legend biotech', 'cystic fibrosis foundation', 'horizon pharmaceuticals', 'korean society of nephrology', 'parent project muscular dystrophy', 'ohio university', 'china postdoctoral science foundation', 'itm', 'haryana state council for science and technology', 'canada research chairs', 'nih common fund', 'lu', 'amsterdam umc', 'siriraj hospital', 'georgia institute of technology', 'uf health cancer center', 'strategic environmental research and development program', 'ingham institute', 'fosu', 'northeast als consortium', 'ms research australia', 'smru', 'msf', 'universidade de vigo', 'shanxi science and technology department', 'kleberg foundation', 'helsinki university central hospital', 'john innes foundation', 'fondazione cenci bolognetti', 'ao', 'spanish ministry of science and technology', 'lingnan normal university', 'redissec', 'virginia commonwealth university', 'idaho state university', 'cancer center', 'university of duisburg-essen', 'nih national institute of environmental health sciences', 'sirf', 'sbs', 'u.s. air force', 'ups', 'regione basilicata', 'japan science and technology corporation', 'teijin pharma', 'cirmf', 'mbf', 'sichuan agricultural university', 'nih blueprint for neuroscience research', 'australian catholic university', 'kmitl', 'sontag foundation', 'australian housing and urban research institute', 'ccd', 'meta', 'national scientific and technical research council', 'small business innovation research', 'xuzhou medical university', 'china agricultural research system', 'infosys foundation', 'ud', 'institute of organic chemistry and biochemistry of the czech academy of sciences', 'american college ...
# The match count betweenNER_spacy_lg_orgimproved version I and Crossref improved version I :
# 9593
# ['international tennis federation', 'national taiwan ocean university', 'global health', 'innovate uk', 'fmd', 'industrial technology research institute', 'hospital universiti sains malaysia', 'national council for scientific and technological development', 'mdic', 'royal institute of technology', 'autonomous university of chapingo', 'mazums', 'montreal general hospital foundation', 'australian genome research facility', 'dh', 'shanghai municipal health and family planning commission', 'tsgh', 'beth israel deaconess medical center', 'frc', 'beijing foreign studies university', 'astra', 'spa', 'agria pet insurance', 'lcm', 'schweizerische herzstiftung', 'hlf', 'cai', 'diabetes australia', 'sums', 'aag', 'promotion and mutual aid corporation for private schools of japan', 'bialystok university of technology', 'hunan provincial science and technology plan project', 'national social science foundation', 'embrapa genetic resources and biotechnology', 'ubc', 'naval medical research center', 'john s. latsis public benefit foundation', 'virbac', 'university of macedonia', 'southwest hospital', 'arsla', 'als association', 'institute for critical technology and applied science', 'lg chem ltd.', 'sweden-america foundation', 'lccc', 'thailand development research institute', 'thailand center of excellence for life sciences', 'sic', 'uhs lahore', 'institut de bioenginyeria de catalunya', 'kaul pediatric research institute', 'business finland', 'ibm', 'bavarian state ministry for science and art', 'pb', 'college of agriculture and natural resources', 'monell chemical senses center', 'burroughs wellcome fund', 'u.s. army corps of engineers', 'shenzhen science and technology innovation commission', 'czech science foundation', 'autonomous community of the region of murcia', 'stfc', 'world academy of sciences', 'united states department of energy', 'japan epilepsy research foundation', 'nscc-tj', 'dae', 'korea international cooperation agency', 'pharmaceutical society of western australia', 'kyorin university school of medicine', 'u.s. national institute on aging', 'fs', 'ga', 'mest', 'tsc', 'wenzhou science and technology bureau', 'italian medicines agency', 'national institute of standards and technology', 'tms', 'legend biotech', 'cystic fibrosis foundation', 'horizon pharmaceuticals', 'korean society of nephrology', 'icmc', 'ohio university', 'cnfs', 'china postdoctoral science foundation', 'itm', 'haryana state council for science and technology', 'canada research chairs', 'nih common fund', 'amsterdam umc', 'siriraj hospital', 'georgia institute of technology', 'ingham institute', 'fosu', 'northeast als consortium', 'ms research australia', 'smru', 'msf', 'universidade de vigo', 'shanxi science and technology department', 'kleberg foundation', 'helsinki university central hospital', 'john innes foundation', 'ao', 'spanish ministry of science and technology', 'lingnan normal university', 'redissec', 'virginia commonwealth university', 'idaho state university', 'cancer center', 'university of duisburg-essen', 'nih national institute of environmental health sciences', 'sirf', 'sbs', 'u.s. air force', 'ups', 'regione basilicata', 'japan science and technology corporation', 'teijin pharma', 'cirmf', 'sichuan agricultural university', 'nih blueprint for neuroscience research', 'australian catholic university', 'sontag foundation', 'australian housing and urban research institute', 'irish centre for high end computing', 'meta', 'national scientific and technical research council', 'small business innovation research', 'xuzhou medical university', 'china agricultural research system', 'infosys foundation', 'ud', 'american society for radiation oncology', 'fcdo', 'adc', 'national space biomedical research institute', 'rheumasearch foundation', 'amsterdam university medical centers', 'university of oulu', 'university of kwazulu-natal', 'kangwon national university', 'nedo', 'oklahoma center for the advancement of science and technology', 'simtech', ...
# The match count betweenNER_Flair_orgimproved version I and Crossref improved version I :
# 11661
# ['shinshu university', 'loughborough university', 'zaozhuang university', 'international tennis federation', 'national taiwan ocean university', 'seoul national university', 'hasso plattner foundation', 'sppu', 'kreitman school of advanced graduate studies', 'innovate uk', 'laqv', 'fmd', 'industrial technology research institute', 'baylor university medical center', 'epidemiological and clinical research information network', 'hospital universiti sains malaysia', 'srcd', 'national council for scientific and technological development', 'nidilrr', 'uclh', 'mdic', 'inee', 'royal institute of technology', 'b', 'autonomous university of chapingo', 'national agrarian university', 'hp', 'montreal general hospital foundation', 'australian genome research facility', 'huashan hospital', 'society for maternal fetal medicine', 'dh', 'shanghai municipal health and family planning commission', 'ocp foundation', 'university of canberra', 'karlstad university', 'royal swedish academy of sciences', 'ramaciotti foundations', 'universidad panamericana', 'vu', 'national institute of neurological disorders and stroke', 'beijing jiaotong university', 'tsgh', 'cmrf', 'beth israel deaconess medical center', 'kansai medical university', 'veracyte inc', 'frc', 'ifn', 'gobierno del principado de asturias', 'indiana state department of health', 'es', 'beijing foreign studies university', 'astra', 'mbg', 'spa', 'scl', 'agria pet insurance', 'lcm', 'guangdong pharmaceutical university', 'ministry of justice', 'marie sklodowska-curie actions', 'university of dar es salaam', 'ibaraki university', 'schweizerische herzstiftung', 'nina', 'hlf', 'dioraphte foundation', 'insp', 'cai', 'diabetes australia', 'sums', 'saw', 'danish ministry of health', 'public health institute', 'centre for cognitive ageing and cognitive epidemiology', 'national drug research institute', 'faculty of medicine and health', 'baafs', 'aag', 'cra', 'promotion and mutual aid corporation for private schools of japan', 'bialystok university of technology', 'australian research council centre of excellence for mathematical and statistical frontiers', 'kisr', 'brazilian federal agency for the support and evaluation of graduate education', 'arrow bone marrow transplant foundation', 'ugr', 'robert wood johnson medical school', 'national social science foundation', 'embrapa genetic resources and biotechnology', 'institut universitaire de france', 'victoria university', 'ubc', 'naval medical research center', 'petrus och augusta hedlunds stiftelse', 'twf', 'wuhan national biosafety laboratory', 'john s. latsis public benefit foundation', 'kwansei gakuin university', 'wp', 'zhejiang sci-tech university', 'ndmc', 'virbac', 'swedish transport administration', 'chengdu university of traditional chinese medicine', 'nri', 'taylor family institute for innovative psychiatric research', 'lembaga ilmu pengetahuan indonesia', 'university of macedonia', 'university of isfahan', 'hennepin healthcare research institute', 'southwest hospital', 'tu wien bibliothek', 'natural science foundation of anhui province', 'arsla', 'als association', 'institute for critical technology and applied science', 'henri and flore lesieur foundation', 'sweden-america foundation', 'thailand development research institute', 'lccc', 'thailand center of excellence for life sciences', 'imperial experimental cancer medicine centre', 'asu', 'darwin trust', 'vlir-uos', 'education department of henan province', 'sic', 'uhs lahore', 'institut de bioenginyeria de catalunya', 'shanghai baoshan science and technology commission', 'kaul pediatric research institute', 'frederick national laboratory for cancer research', 'national institute on disability and rehabilitation research', 'business finland', 'ibm', 'mount allison university', 'pb', 'college of agriculture and natural resources', 'compete', 'burroughs wellcome fund', 'portage health foundation', 'u.s. army corps of engineers', 'us highbush blueberry council', 'shenzhen science and tec ...
# ********************************************************************************************************
# The match count betweenNER_spacy_sm_orgimproved version II and Crossref improved version II :
# 7774
# ['oregon clinical & translational research institute', 'shenyang science & technology bureau', 'national taiwan ocean university', 'global health', 'innovate uk', 'laqv', 'fmd', 'industrial technology research institute', 'hospital universiti sains malaysia', 'royal institute of technology', 'fujian provincial science & technology department', 'dh', 'university of electronic science & technology of china', 'tsgh', 'beth israel deaconess medical center', 'frc', 'beijing foreign studies university', 'astra', 'spa', 'agria pet insurance', 'lcm', 'the university grants committee', 'hlf', 'cai', 'diabetes australia', 'aag', 'the manitoba centre for health policy', 'bialystok university of technology', 'national social science foundation', 'ubc', 'naval medical research center', 'petrus och augusta hedlunds stiftelse', 'wp', 'virbac', 'university of macedonia', 'southwest hospital', 'als association', 'lg chem ltd.', 'lccc', 'thailand development research institute', 'darwin trust', 'vlir-uos', 'sic', 'kaul pediatric research institute', 'udec', 'business finland', 'ibm', 'pb', 'the chinese university of hong kong', 'monell chemical senses center', 'burroughs wellcome fund', 'czech science foundation', 'stfc', 'janssen alzheimer immunotherapy research & development', 'immunodeficiency canada', 'dae', 'kyorin university school of medicine', 'fs', 'ga', 'tsc', 'italian medicines agency', 'vci', 'the digestive medical coordinated development center of beijing hospitals authority', 'tms', 'cystic fibrosis foundation', 'horizon pharmaceuticals', 'icmc', 'ohio university', 'china postdoctoral science foundation', 'itm', 'canada research chairs', 'nih common fund', 'amsterdam umc', 'samara university', 'siriraj hospital', 'georgia institute of technology', 'fosu', 'northeast als consortium', 'ms research australia', 'msf', 'kleberg foundation', 'helsinki university central hospital', 'ao', 'lingnan normal university', 'redissec', 'virginia commonwealth university', 'idaho state university', 'cancer center', 'the sontag foundation', 'university of duisburg-essen', 'sirf', 'sbs', 'u.s. air force', 'ups', 'wuxi science & technology bureau', 'cirmf', 'mbf', 'sichuan agricultural university', 'nih blueprint for neuroscience research', 'australian catholic university', 'kmitl', 'the national eye institute', 'ccd', 'meta', 'small business innovation research', 'xuzhou medical university', 'china agricultural research system', 'ud', 'ministry of science, innovation & universities', 'american college of preventive medicine', 'american society for radiation oncology', 'adc', 'amsterdam university medical centers', 'university of oulu', 'kunming university of science & technology', 'university of kwazulu-natal', 'kangwon national university', 'nedo', 'cei', 'simtech', 'natural science foundation of shaanxi provincial department of education', 'ecdc', 'cgd', 'baef', 'cpc', 'the mayday fund', 'vinif', 'norwegian institute of public health', 'institute of high energy physics', 'empir', 'university of karachi', 'gansu university of chinese medicine', 'chung-ang university', 'shiraz university', 'searca', 'rra', 'the health research board', 'sso', 'university of south dakota', 'frq', 'university of louisville', 'office of research', 'vcf', 'the university of texas system', 'schizophrenia research institute', 'german research foundation', 'hrsa', 'vestfold hospital trust', 'peking university first hospital', 'university of castilla-la mancha', 'university of minnesota', 'pemf', 'national oceanic & atmospheric administration', 'raeng', 'aj', 'icbf', 'ciber-bbn', 'alberta wheat commission', 'universidad austral de chile', 'cbg', 'universidad de santiago de compostela', 'university college dublin', 'gls', 'ohio supercomputer center', 'fundesalud', 'orise', 'dexcom, inc.', 'johns hopkins', 'transilvania university of brasov', 'bc cancer foundation', 'university of the western cape', 'seed', 'edu', 'irme', 'mht', 'jiaxing university', 'aida', 'arrowhead pharmac ...
# The match count betweenNER_spacy_md_orgimproved version II and Crossref improved version II :
# 8057
# ['shenyang science & technology bureau', 'national taiwan ocean university', 'global health', 'innovate uk', 'laqv', 'industrial technology research institute', 'royal institute of technology', 'fujian provincial science & technology department', 'dh', 'university of electronic science & technology of china', 'tsgh', 'beth israel deaconess medical center', 'frc', 'beijing foreign studies university', 'astra', 'spa', 'agria pet insurance', 'lcm', 'the university grants committee', 'schweizerische herzstiftung', 'hlf', 'cai', 'diabetes australia', 'sums', 'the manitoba centre for health policy', 'bialystok university of technology', 'national social science foundation', 'ubc', 'naval medical research center', 'wuhan national biosafety laboratory', 'national program for support of top-notch young professionals', 'wp', 'virbac', 'a-step', 'university of macedonia', 'southwest hospital', 'arsla', 'als association', 'wcr', 'lg chem ltd.', 'lccc', 'thailand development research institute', 'darwin trust', 'vlir-uos', 'kaul pediatric research institute', 'business finland', 'ibm', 'pb', 'the chinese university of hong kong', 'monell chemical senses center', 'burroughs wellcome fund', 'czech science foundation', 'stfc', 'janssen alzheimer immunotherapy research & development', 'immunodeficiency canada', 'universidade federal de santa catarina', 'dae', 'kyorin university school of medicine', 'fs', 'ga', 'mest', 'tsc', 'italian medicines agency', 'vci', 'the digestive medical coordinated development center of beijing hospitals authority', 'tms', 'legend biotech', 'cystic fibrosis foundation', 'horizon pharmaceuticals', 'parent project muscular dystrophy', 'ohio university', 'china postdoctoral science foundation', 'itm', 'canada research chairs', 'nih common fund', 'lu', 'amsterdam umc', 'siriraj hospital', 'georgia institute of technology', 'fosu', 'northeast als consortium', 'ms research australia', 'smru', 'msf', 'kleberg foundation', 'helsinki university central hospital', 'fondazione cenci bolognetti', 'ao', 'lingnan normal university', 'redissec', 'virginia commonwealth university', 'idaho state university', 'cancer center', 'the sontag foundation', 'university of duisburg-essen', 'sirf', 'sbs', 'u.s. air force', 'ups', 'regione basilicata', 'teijin pharma', 'wuxi science & technology bureau', 'cirmf', 'mbf', 'sichuan agricultural university', 'australian catholic university', 'kmitl', 'the national eye institute', 'ccd', 'meta', 'small business innovation research', 'xuzhou medical university', 'china agricultural research system', 'ud', 'ministry of science, innovation & universities', 'american college of preventive medicine', 'american society for radiation oncology', 'fcdo', 'adc', 'amsterdam university medical centers', 'university of oulu', 'kunming university of science & technology', 'university of kwazulu-natal', 'kangwon national university', 'nedo', 'cei', 'simtech', 'ecdc', 'cgd', 'baef', 'cpc', 'the mayday fund', 'vinif', 'norwegian institute of public health', 'empir', 'gansu university of chinese medicine', 'chung-ang university', 'shiraz university', 'searca', 'rra', 'the health research board', 'second affiliated hospital of soochow university', 'university of south dakota', 'frq', 'university of louisville', 'office of research', 'rgf', 'the university of texas system', 'national basic research program of china', 'ceu', 'schizophrenia research institute', 'german research foundation', 'hrsa', 'vestfold hospital trust', 'peking university first hospital', 'university of castilla-la mancha', 'university of minnesota', 'national oceanic & atmospheric administration', 'raeng', 'aj', 'icbf', 'national forestry & grassland administration', 'nmsf', 'ciber-bbn', 'alberta wheat commission', 'universidad austral de chile', 'cbg', 'universidad de santiago de compostela', 'university college dublin', 'gls', 'alexander von humboldt foundation', 'ohio supercomputer center', 'orise', 'dexcom, inc.', 'johns hopkins', 'transilvan ...
# The match count betweenNER_spacy_lg_orgimproved version II and Crossref improved version II :
# 8085
# ['national taiwan ocean university', 'global health', 'innovate uk', 'fmd', 'industrial technology research institute', 'hospital universiti sains malaysia', 'mdic', 'royal institute of technology', 'fujian provincial science & technology department', 'mazums', 'dh', 'university of electronic science & technology of china', 'tsgh', 'beth israel deaconess medical center', 'frc', 'beijing foreign studies university', 'astra', 'spa', 'agria pet insurance', 'lcm', 'the university grants committee', 'schweizerische herzstiftung', 'hlf', 'cai', 'diabetes australia', 'sums', 'aag', 'the manitoba centre for health policy', 'bialystok university of technology', 'national social science foundation', 'ubc', 'naval medical research center', 'virbac', 'university of macedonia', 'southwest hospital', 'arsla', 'als association', 'lg chem ltd.', 'lccc', 'thailand development research institute', 'sic', 'uhs lahore', 'kaul pediatric research institute', 'business finland', 'ibm', 'pb', 'the chinese university of hong kong', 'monell chemical senses center', 'burroughs wellcome fund', 'czech science foundation', 'stfc', 'united states department of energy', 'janssen alzheimer immunotherapy research & development', 'nscc-tj', 'dae', 'kyorin university school of medicine', 'fs', 'ga', 'mest', 'tsc', 'italian medicines agency', 'the digestive medical coordinated development center of beijing hospitals authority', 'tms', 'legend biotech', 'cystic fibrosis foundation', 'horizon pharmaceuticals', 'icmc', 'ohio university', 'cnfs', 'china postdoctoral science foundation', 'itm', 'canada research chairs', 'nih common fund', 'amsterdam umc', 'siriraj hospital', 'georgia institute of technology', 'fosu', 'northeast als consortium', 'ms research australia', 'smru', 'msf', 'kleberg foundation', 'helsinki university central hospital', 'ao', 'lingnan normal university', 'redissec', 'virginia commonwealth university', 'idaho state university', 'cancer center', 'the sontag foundation', 'university of duisburg-essen', 'sirf', 'sbs', 'u.s. air force', 'ups', 'regione basilicata', 'teijin pharma', 'wuxi science & technology bureau', 'cirmf', 'sichuan agricultural university', 'australian catholic university', 'the national eye institute', 'meta', 'small business innovation research', 'xuzhou medical university', 'china agricultural research system', 'ud', 'ministry of science, innovation & universities', 'american society for radiation oncology', 'fcdo', 'adc', 'amsterdam university medical centers', 'university of oulu', 'kunming university of science & technology', 'university of kwazulu-natal', 'kangwon national university', 'nedo', 'simtech', 'natural science foundation of shaanxi provincial department of education', 'ecdc', 'baef', 'cpc', 'the mayday fund', 'vinif', 'norwegian institute of public health', 'institute of high energy physics', 'empir', 'gansu university of chinese medicine', 'chung-ang university', 'danube university krems', 'shiraz university', 'rra', 'ibama', 'the health research board', 'sso', 'university of south dakota', 'hbf', 'frq', 'university of louisville', 'vcf', 'state key laboratory of chemical engineering', 'the university of texas system', 'national basic research program of china', 'schizophrenia research institute', 'german research foundation', 'hrsa', 'vestfold hospital trust', 'peking university first hospital', 'university of castilla-la mancha', 'university of minnesota', 'national oceanic & atmospheric administration', 'raeng', 'aj', 'icbf', 'sanofi k.k.', 'ciber-bbn', 'alberta wheat commission', 'universidad austral de chile', 'universidad de santiago de compostela', 'university college dublin', 'gls', 'alexander von humboldt foundation', 'ohio supercomputer center', 'robert a. welch foundation', 'orise', 'dexcom, inc.', 'johns hopkins', 'bc cancer foundation', 'university of the western cape', 'seed', 'japan agency for medical research & development', 'irme', 'mht', 'aida', 'arrowhead pharmaceuticals', 'spanish state res ...
# The match count betweenNER_Flair_orgimproved version II and Crossref improved version II :
# 11680
# ['shinshu university', 'loughborough university', 'oregon clinical & translational research institute', 'zaozhuang university', 'international tennis federation', 'national taiwan ocean university', 'seoul national university', 'hasso plattner foundation', 'the university of manchester', 'sppu', 'kreitman school of advanced graduate studies', 'innovate uk', 'laqv', 'fmd', 'industrial technology research institute', 'baylor university medical center', 'hospital universiti sains malaysia', 'srcd', 'nidilrr', 'uclh', 'mdic', 'inee', 'department of geology & geophysics', 'royal institute of technology', 'foundation for the promotion of health & biomedical research of valencia region', 'b', 'fujian provincial science & technology department', 'office of energy efficiency & renewable energy', 'national agrarian university', 'hp', 'montreal general hospital foundation', 'australian genome research facility', 'huashan hospital', 'society for maternal fetal medicine', 'dh', 'ocp foundation', 'university of canberra', 'karlstad university', 'royal swedish academy of sciences', 'ramaciotti foundations', 'universidad panamericana', 'vu', 'university of electronic science & technology of china', 'beijing jiaotong university', 'tsgh', 'henri & flore lesieur foundation', 'cmrf', 'beth israel deaconess medical center', 'kansai medical university', 'veracyte inc', 'frc', 'ifn', 'gobierno del principado de asturias', 'indiana state department of health', 'es', 'beijing foreign studies university', 'astra', 'mbg', 'spa', 'scl', 'agria pet insurance', 'lcm', 'guangdong pharmaceutical university', 'ministry of justice', 'marie sklodowska-curie actions', 'university of dar es salaam', 'ibaraki university', 'schweizerische herzstiftung', 'nina', 'hlf', 'dioraphte foundation', 'insp', 'cai', 'diabetes australia', 'sums', 'saw', 'danish ministry of health', 'public health institute', 'national drug research institute', 'baafs', 'aag', 'colorado department of public health & environment', 'cra', 'bialystok university of technology', 'kisr', 'arrow bone marrow transplant foundation', 'ugr', 'robert wood johnson medical school', 'national social science foundation', 'institut universitaire de france', 'victoria university', 'development & reform commission of jilin province', 'ubc', 'naval medical research center', 'petrus och augusta hedlunds stiftelse', 'twf', 'spanish ministry of science & technology', 'wuhan national biosafety laboratory', 'kwansei gakuin university', 'wp', 'zhejiang sci-tech university', 'ndmc', 'virbac', 'swedish transport administration', 'chengdu university of traditional chinese medicine', 'nri', 'taylor family institute for innovative psychiatric research', 'lembaga ilmu pengetahuan indonesia', 'university of macedonia', 'university of isfahan', 'national institute for health & care excellence', 'hennepin healthcare research institute', 'the world academy of sciences', 'southwest hospital', 'tu wien bibliothek', 'natural science foundation of anhui province', 'arsla', 'als association', 'sweden-america foundation', 'lccc', 'thailand development research institute', 'thailand center of excellence for life sciences', 'imperial experimental cancer medicine centre', 'asu', 'darwin trust', 'vlir-uos', 'education department of henan province', 'sic', 'uhs lahore', 'institut de bioenginyeria de catalunya', 'kaul pediatric research institute', 'frederick national laboratory for cancer research', 'business finland', 'ibm', 'mount allison university', 'pb', 'center for health technology & services research', 'the chinese university of hong kong', 'compete', 'burroughs wellcome fund', 'portage health foundation', 'u.s. army corps of engineers', 'czech science foundation', 'the health foundation', 'autonomous community of the region of murcia', 'stfc', 'de.nbi', 'foncyt', 'united states department of energy', 'epigenmed', 'dost', 'college of chemistry', 'peg', 'japan epilepsy research foundation', 'janssen alzheimer immunotherapy research  ...
# ********************************************************************************************************
# The match count betweenNER_spacy_sm_orgimproved version III and Crossref improved version III :
# 8143
# ['national taiwan ocean university', 'global health', 'innovate uk', 'laqv', 'fmd', 'industrial technology research institute', 'hospital universiti sains malaysia', 'royal institute of technology', 'dh', 'shanghai municipal health and family planning commission', 'vall dhebron university hospital', 'tsgh', 'beth israel deaconess medical center', 'frc', 'beijing foreign studies university', 'astra', 'spa', 'agria pet insurance', 'lcm', 'the university grants committee', 'hlf', 'the walter and eliza hall institute of medical research', 'cai', 'diabetes australia', 'aag', 'the manitoba centre for health policy', 'bialystok university of technology', 'hunan provincial science and technology plan project', 'national social science foundation', 'embrapa genetic resources and biotechnology', 'ubc', 'naval medical research center', 'petrus och augusta hedlunds stiftelse', 'wp', 'virbac', 'university of macedonia', 'southwest hospital', 'als association', 'lccc', 'thailand development research institute', 'darwin trust', 'sic', 'kaul pediatric research institute', 'udec', 'childrens hospital of wisconsin', 'business finland', 'ibm', 'pb', 'the chinese university of hong kong', 'monell chemical senses center', 'burroughs wellcome fund', 'shenzhen science and technology innovation commission', 'foreign commonwealth & development office', 'czech science foundation', 'stfc', 'nbf', 'immunodeficiency canada', 'dae', 'kyorin university school of medicine', 'fs', 'ga', 'tsc', 'wenzhou science and technology bureau', 'italian medicines agency', 'vci', 'the digestive medical coordinated development center of beijing hospitals authority', 'tms', 'cystic fibrosis foundation', 'horizon pharmaceuticals', 'icmc', 'ohio university', 'china postdoctoral science foundation', 'itm', 'haryana state council for science and technology', 'canada research chairs', 'nih common fund', 'lu', 'amsterdam umc', 'samara university', 'siriraj hospital', 'georgia institute of technology', 'btc', 'fosu', 'universidad de castillala mancha', 'northeast als consortium', 'ms research australia', 'msf', 'shanxi science and technology department', 'kleberg foundation', 'helsinki university central hospital', 'ao', 'spanish ministry of science and technology', 'lingnan normal university', 'redissec', 'virginia commonwealth university', 'idaho state university', 'cancer center', 'the sontag foundation', 'morinaga milk industry co ltd', 'sirf', 'sbs', 'ups', 'japan science and technology corporation', 'cirmf', 'mbf', 'sichuan agricultural university', 'nih blueprint for neuroscience research', 'australian catholic university', 'kmitl', 'the national eye institute', 'ccd', 'meta', 'small business innovation research', 'xuzhou medical university', 'china agricultural research system', 'ud', 'american college of preventive medicine', 'american society for radiation oncology', 'adc', 'amsterdam university medical centers', 'university of oulu', 'kangwon national university', 'nedo', 'cei', 'simtech', 'natural science foundation of shaanxi provincial department of education', 'ecdc', 'cgd', 'baef', 'hok', 'fondation armandfrappier', 'cpc', 'the mayday fund', 'vinif', 'norwegian institute of public health', 'institute of high energy physics', 'empir', 'university of karachi', 'gansu university of chinese medicine', 'shiraz university', 'searca', 'rra', 'the health research board', 'tokyo university of agriculture and technology', 'sso', 'university of south dakota', 'frq', 'university of louisville', 'office of research', 'vcf', 'the university of texas system', 'apple inc', 'schizophrenia research institute', 'german research foundation', 'hrsa', 'vestfold hospital trust', 'peking university first hospital', 'university of minnesota', 'pemf', 'raeng', 'aj', 'icbf', 'alberta wheat commission', 'universidad austral de chile', 'cbg', 'universidad de santiago de compostela', 'university college dublin', 'gls', 'ohio supercomputer center', 'fundesalud', 'orise', 'johns hopkins', 'trans ...
# The match count betweenNER_spacy_md_orgimproved version III and Crossref improved version III :
# 8411
# ['national taiwan ocean university', 'global health', 'innovate uk', 'laqv', 'fmd', 'industrial technology research institute', 'national council for scientific and technological development', 'royal institute of technology', 'dh', 'vall dhebron university hospital', 'tsgh', 'beth israel deaconess medical center', 'veracyte inc', 'frc', 'beijing foreign studies university', 'astra', 'spa', 'agria pet insurance', 'lcm', 'the university grants committee', 'schweizerische herzstiftung', 'hlf', 'cai', 'diabetes australia', 'sums', 'the manitoba centre for health policy', 'bialystok university of technology', 'hunan provincial science and technology plan project', 'national social science foundation', 'embrapa genetic resources and biotechnology', 'ior', 'ubc', 'naval medical research center', 'wuhan national biosafety laboratory', 'wp', 'virbac', 'university of macedonia', 'southwest hospital', 'arsla', 'als association', 'wcr', 'lccc', 'thailand development research institute', 'darwin trust', 'kaul pediatric research institute', 'business finland', 'ibm', 'pb', 'the chinese university of hong kong', 'monell chemical senses center', 'burroughs wellcome fund', 'shenzhen science and technology innovation commission', 'czech science foundation', 'stfc', 'immunodeficiency canada', 'universidade federal de santa catarina', 'dae', 'kyorin university school of medicine', 'fs', 'ga', 'mest', 'tsc', 'jparc', 'wenzhou science and technology bureau', 'italian medicines agency', 'vci', 'the digestive medical coordinated development center of beijing hospitals authority', 'tms', 'legend biotech', 'cystic fibrosis foundation', 'horizon pharmaceuticals', 'parent project muscular dystrophy', 'ohio university', 'china postdoctoral science foundation', 'itm', 'haryana state council for science and technology', 'canada research chairs', 'nih common fund', 'lu', 'amsterdam umc', 'siriraj hospital', 'georgia institute of technology', 'btc', 'strategic environmental research and development program', 'fosu', 'universidad de castillala mancha', 'northeast als consortium', 'ms research australia', 'smru', 'msf', 'childrens healthcare of atlanta', 'shanxi science and technology department', 'kleberg foundation', 'helsinki university central hospital', 'fondazione cenci bolognetti', 'ao', 'spanish ministry of science and technology', 'lingnan normal university', 'redissec', 'virginia commonwealth university', 'idaho state university', 'cancer center', 'the sontag foundation', 'morinaga milk industry co ltd', 'sirf', 'sbs', 'ups', 'regione basilicata', 'japan science and technology corporation', 'teijin pharma', 'cirmf', 'mbf', 'sichuan agricultural university', 'australian catholic university', 'kmitl', 'the national eye institute', 'ccd', 'meta', 'small business innovation research', 'xuzhou medical university', 'china agricultural research system', 'ud', 'american college of preventive medicine', 'american society for radiation oncology', 'fcdo', 'adc', 'amsterdam university medical centers', 'university of oulu', 'kangwon national university', 'nedo', 'cei', 'simtech', 'oklahoma center for the advancement of science and technology', 'ecdc', 'cgd', 'baef', 'hok', 'fondation armandfrappier', 'cpc', 'the mayday fund', 'vinif', 'norwegian institute of public health', 'department of atomic energy government of india', 'empir', 'gansu university of chinese medicine', 'shiraz university', 'searca', 'rra', 'the health research board', 'second affiliated hospital of soochow university', 'tokyo university of agriculture and technology', 'university of south dakota', 'frq', 'university of louisville', 'office of research', 'rgf', 'the university of texas system', 'national basic research program of china', 'ceu', 'apple inc', 'major science and technology projects of zhejiang province', 'schizophrenia research institute', 'german research foundation', 'hrsa', 'vestfold hospital trust', 'peking university first hospital', 'university of minnesota', 'raeng', 'aj',  ...
# The match count betweenNER_spacy_lg_orgimproved version III and Crossref improved version III :
# 8426
# ['national taiwan ocean university', 'global health', 'innovate uk', 'fmd', 'industrial technology research institute', 'hospital universiti sains malaysia', 'national council for scientific and technological development', 'mdic', 'royal institute of technology', 'mazums', 'dh', 'shanghai municipal health and family planning commission', 'vall dhebron university hospital', 'tsgh', 'beth israel deaconess medical center', 'veracyte inc', 'frc', 'beijing foreign studies university', 'astra', 'spa', 'agria pet insurance', 'lcm', 'the university grants committee', 'schweizerische herzstiftung', 'hlf', 'cai', 'diabetes australia', 'sums', 'aag', 'the manitoba centre for health policy', 'bialystok university of technology', 'hunan provincial science and technology plan project', 'national social science foundation', 'embrapa genetic resources and biotechnology', 'ior', 'ubc', 'naval medical research center', 'wp', 'virbac', 'university of macedonia', 'southwest hospital', 'arsla', 'als association', 'lccc', 'thailand development research institute', 'sic', 'uhs lahore', 'kaul pediatric research institute', 'childrens hospital of wisconsin', 'business finland', 'ibm', 'pb', 'the chinese university of hong kong', 'monell chemical senses center', 'burroughs wellcome fund', 'shenzhen science and technology innovation commission', 'czech science foundation', 'stfc', 'united states department of energy', 'dae', 'kyorin university school of medicine', 'fs', 'ga', 'mest', 'tsc', 'jparc', 'wenzhou science and technology bureau', 'italian medicines agency', 'the digestive medical coordinated development center of beijing hospitals authority', 'tms', 'legend biotech', 'cystic fibrosis foundation', 'horizon pharmaceuticals', 'icmc', 'ohio university', 'cnfs', 'china postdoctoral science foundation', 'itm', 'haryana state council for science and technology', 'canada research chairs', 'nih common fund', 'lu', 'amsterdam umc', 'a alfred taubman medical research institute', 'siriraj hospital', 'georgia institute of technology', 'btc', 'fosu', 'edward p evans foundation', 'universidad de castillala mancha', 'northeast als consortium', 'ms research australia', 'smru', 'msf', 'shanxi science and technology department', 'kleberg foundation', 'helsinki university central hospital', 'wallenberg centre for molecular and translational medicine university of gothenburg', 'ao', 'spanish ministry of science and technology', 'lingnan normal university', 'redissec', 'virginia commonwealth university', 'idaho state university', 'cancer center', 'the sontag foundation', 'morinaga milk industry co ltd', 'sirf', 'sbs', 'ups', 'regione basilicata', 'japan science and technology corporation', 'teijin pharma', 'cirmf', 'mbf', 'sichuan agricultural university', 'australian catholic university', 'the national eye institute', 'meta', 'small business innovation research', 'xuzhou medical university', 'china agricultural research system', 'ud', 'american society for radiation oncology', 'fcdo', 'adc', 'amsterdam university medical centers', 'university of oulu', 'kangwon national university', 'nedo', 'oklahoma center for the advancement of science and technology', 'simtech', 'natural science foundation of shaanxi provincial department of education', 'ecdc', 'cgd', 'baef', 'hok', 'fondation armandfrappier', 'cpc', 'the mayday fund', 'vinif', 'norwegian institute of public health', 'institute of high energy physics', 'empir', 'gansu university of chinese medicine', 'danube university krems', 'shiraz university', 'rra', 'ibama', 'the health research board', 'tokyo university of agriculture and technology', 'sso', 'university of south dakota', 'hbf', 'cfb', 'frq', 'university of louisville', 'vcf', 'state key laboratory of chemical engineering', 'the university of texas system', 'national basic research program of china', 'apple inc', 'schizophrenia research institute', 'german research foundation', 'hrsa', 'vestfold hospital trust', 'peking university first hospital', 'univers ...
# The match count betweenNER_Flair_orgimproved version III and Crossref improved version III :
# 12027
# ...
# The match count betweenNER_spacy_md_orgimproved version IV and Crossref improved version IV :
# 9961
# ['shenyang science & technology bureau', 'international tennis federation', 'national taiwan ocean university', 'global health', 'innovate uk', 'laqv', 'fmd', 'industrial technology research institute', 'royal institute of technology', 'fujian provincial science & technology department', 'earmarked fund for modern agroindustry technology research system', 'autonomous university of chapingo', 'montreal general hospital foundation', 'australian genome research facility', 'society for maternal fetal medicine', 'dh', 'vall dhebron university hospital', 'university of electronic science & technology of china', 'tsgh', 'beth israel deaconess medical center', 'veracyte inc', 'frc', 'beijing foreign studies university', 'astra', 'spa', 'agria pet insurance', 'lcm', 'university of dar es salaam', 'schweizerische herzstiftung', 'hlf', 'cai', 'diabetes australia', 'sums', 'miller institute', 'bialystok university of technology', 'national social science foundation', 'ior', 'ubc', 'naval medical research center', 'wuhan national biosafety laboratory', 'wp', 'virbac', 'university of macedonia', 'southwest hospital', 'arsla', 'als association', 'wcr', 'lccc', 'thailand development research institute', 'thailand center of excellence for life sciences', 'us civilian research & development foundation', 'darwin trust', 'institut de bioenginyeria de catalunya', 'kaul pediatric research institute', 'business finland', 'ibm', 'pb', 'monell chemical senses center', 'burroughs wellcome fund', 'czech science foundation', 'autonomous community of the region of murcia', 'stfc', 'world academy of sciences', 'united states department of energy', 'japan epilepsy research foundation', 'janssen alzheimer immunotherapy research & development', 'immunodeficiency canada', 'universidade federal de santa catarina', 'us national nuclear security administration', 'dae', 'korea international cooperation agency', 'pharmaceutical society of western australia', 'kyorin university school of medicine', 'fs', 'ga', 'mest', 'tsc', 'jparc', 'italian medicines agency', 'vci', 'tms', 'legend biotech', 'cystic fibrosis foundation', 'louisiana clinical & translational science center', 'horizon pharmaceuticals', 'korean society of nephrology', 'parent project muscular dystrophy', 'ohio university', 'china postdoctoral science foundation', 'shenzhen municipal development & reform commission', 'itm', 'canada research chairs', 'nih common fund', 'lu', 'amsterdam umc', 'a alfred taubman medical research institute', 'siriraj hospital', 'georgia institute of technology', 'btc', 'uf health cancer center', 'ingham institute', 'fosu', 'edward p evans foundation', 'universidad de castillala mancha', 'northeast als consortium', 'ms research australia', 'smru', 'msf', 'childrens healthcare of atlanta', 'universidade de vigo', 'kleberg foundation', 'joint institute for food safety & applied nutrition', 'helsinki university central hospital', 'john innes foundation', 'fondazione cenci bolognetti', 'ao', 'lingnan normal university', 'redissec', 'virginia commonwealth university', 'idaho state university', 'cancer center', 'morinaga milk industry co ltd', 'nih national institute of environmental health sciences', 'sirf', 'sbs', 'ups', 'regione basilicata', 'teijin pharma', 'wuxi science & technology bureau', 'cirmf', 'mbf', 'sichuan agricultural university', 'nih blueprint for neuroscience research', 'australian catholic university', 'kmitl', 'sontag foundation', 'ccd', 'meta', 'small business innovation research', 'xuzhou medical university', 'china agricultural research system', 'infosys foundation', 'ud', 'american college of preventive medicine', 'american society for radiation oncology', 'fcdo', 'adc', 'national space biomedical research institute', 'rheumasearch foundation', 'amsterdam university medical centers', 'university of oulu', 'kunming university of science & technology', 'nuclear safety & security commission', 'kangwon national university', 'nedo', 'cei', 'simtech', 'ecdc', 'cg ...
# The match count betweenNER_spacy_lg_orgimproved version IV and Crossref improved version IV :
# 9969
# ['oregon clinical & translational research institute', 'national taiwan ocean university', 'international tennis federation', 'global health', 'innovate uk', 'fmd', 'industrial technology research institute', 'hospital universiti sains malaysia', 'mdic', 'royal institute of technology', 'fujian provincial science & technology department', 'earmarked fund for modern agroindustry technology research system', 'autonomous university of chapingo', 'mazums', 'montreal general hospital foundation', 'australian genome research facility', 'dh', 'vall dhebron university hospital', 'university of electronic science & technology of china', 'tsgh', 'beth israel deaconess medical center', 'veracyte inc', 'frc', 'beijing foreign studies university', 'astra', 'spa', 'agria pet insurance', 'lcm', 'schweizerische herzstiftung', 'hlf', 'cai', 'diabetes australia', 'sums', 'aag', 'bialystok university of technology', 'national social science foundation', 'ior', 'ubc', 'naval medical research center', 'wp', 'virbac', 'university of macedonia', 'southwest hospital', 'arsla', 'als association', 'lccc', 'thailand development research institute', 'thailand center of excellence for life sciences', 'us civilian research & development foundation', 'sic', 'uhs lahore', 'institut de bioenginyeria de catalunya', 'kaul pediatric research institute', 'childrens hospital of wisconsin', 'business finland', 'ibm', 'pb', 'monell chemical senses center', 'burroughs wellcome fund', 'czech science foundation', 'autonomous community of the region of murcia', 'stfc', 'world academy of sciences', 'united states department of energy', 'japan epilepsy research foundation', 'janssen alzheimer immunotherapy research & development', 'us national nuclear security administration', 'dae', 'korea international cooperation agency', 'pharmaceutical society of western australia', 'kyorin university school of medicine', 'fs', 'ga', 'mest', 'tsc', 'jparc', 'italian medicines agency', 'tms', 'legend biotech', 'cystic fibrosis foundation', 'louisiana clinical & translational science center', 'horizon pharmaceuticals', 'korean society of nephrology', 'icmc', 'ohio university', 'cnfs', 'china postdoctoral science foundation', 'nih national institute of neurological disorders & stroke', 'shenzhen municipal development & reform commission', 'itm', 'canada research chairs', 'nih common fund', 'lu', 'amsterdam umc', 'a alfred taubman medical research institute', 'siriraj hospital', 'georgia institute of technology', 'btc', 'ingham institute', 'fosu', 'edward p evans foundation', 'universidad de castillala mancha', 'northeast als consortium', 'ms research australia', 'smru', 'msf', 'universidade de vigo', 'kleberg foundation', 'joint institute for food safety & applied nutrition', 'helsinki university central hospital', 'john innes foundation', 'ao', 'lingnan normal university', 'redissec', 'virginia commonwealth university', 'idaho state university', 'cancer center', 'morinaga milk industry co ltd', 'nih national institute of environmental health sciences', 'sirf', 'sbs', 'ups', 'regione basilicata', 'teijin pharma', 'wuxi science & technology bureau', 'cirmf', 'mbf', 'sichuan agricultural university', 'nih blueprint for neuroscience research', 'australian catholic university', 'sontag foundation', 'irish centre for high end computing', 'meta', 'small business innovation research', 'xuzhou medical university', 'china agricultural research system', 'infosys foundation', 'ud', 'american society for radiation oncology', 'fcdo', 'adc', 'national space biomedical research institute', 'rheumasearch foundation', 'amsterdam university medical centers', 'university of oulu', 'kunming university of science & technology', 'nuclear safety & security commission', 'kangwon national university', 'nedo', 'simtech', 'natural science foundation of shaanxi provincial department of education', 'ecdc', 'cgd', 'ministry of science research & technology', 'baef', 'hok', 'fondation armandfrappier', 'cpc', 'nationa ...
# The match count betweenNER_Flair_orgimproved version IV and Crossref improved version IV :
# 11999
# ['shinshu university', 'loughborough university', 'oregon clinical & translational research institute', 'mngha', 'zaozhuang university', 'international tennis federation', 'national taiwan ocean university', 'seoul national university', 'hasso plattner foundation', 'sppu', 'kreitman school of advanced graduate studies', 'innovate uk', 'laqv', 'fmd', 'industrial technology research institute', 'baylor university medical center', 'hospital universiti sains malaysia', 'srcd', 'mws', 'nidilrr', 'uclh', 'mdic', 'inee', 'royal institute of technology', 'foundation for the promotion of health & biomedical research of valencia region', 'b', 'fujian provincial science & technology department', 'office of energy efficiency & renewable energy', 'autonomous university of chapingo', 'national agrarian university', 'hp', 'montreal general hospital foundation', 'australian genome research facility', 'huashan hospital', 'society for maternal fetal medicine', 'dh', 'ocp foundation', 'vall dhebron university hospital', 'university of canberra', 'karlstad university', 'royal swedish academy of sciences', 'ceh', 'ramaciotti foundations', 'universidad panamericana', 'vu', 'university of electronic science & technology of china', 'beijing jiaotong university', 'tsgh', 'henri & flore lesieur foundation', 'cmrf', 'beth israel deaconess medical center', 'kansai medical university', 'veracyte inc', 'frc', 'ifn', 'gobierno del principado de asturias', 'indiana state department of health', 'es', 'beijing foreign studies university', 'aasp', 'astra', 'mbg', 'spa', 'scl', 'agria pet insurance', 'lcm', 'guangdong pharmaceutical university', 'ministry of justice', 'university of dar es salaam', 'ibaraki university', 'schweizerische herzstiftung', 'nina', 'hlf', 'dioraphte foundation', 'insp', 'cai', 'diabetes australia', 'saw', 'sums', 'guangzhou science technology & innovation commission', 'danish ministry of health', 'public health institute', 'national drug research institute', 'baafs', 'aag', 'colorado department of public health & environment', 'cra', 'bialystok university of technology', 'kisr', 'arrow bone marrow transplant foundation', 'ugr', 'robert wood johnson medical school', 'national social science foundation', 'ior', 'institut universitaire de france', 'victoria university', 'development & reform commission of jilin province', 'ubc', 'naval medical research center', 'petrus och augusta hedlunds stiftelse', 'twf', 'spanish ministry of science & technology', 'wuhan national biosafety laboratory', 'kwansei gakuin university', 'wp', 'ndmc', 'virbac', 'swedish transport administration', 'chengdu university of traditional chinese medicine', 'nri', 'taylor family institute for innovative psychiatric research', 'lembaga ilmu pengetahuan indonesia', 'university of macedonia', 'university of isfahan', 'national institute for health & care excellence', 'hennepin healthcare research institute', 'southwest hospital', 'tu wien bibliothek', 'natural science foundation of anhui province', 'arsla', 'als association', 'lccc', 'thailand development research institute', 'thailand center of excellence for life sciences', 'imperial experimental cancer medicine centre', 'us civilian research & development foundation', 'asu', 'darwin trust', 'education department of henan province', 'sic', 'uhs lahore', 'institut de bioenginyeria de catalunya', 'kaul pediatric research institute', 'frederick national laboratory for cancer research', 'business finland', 'ibm', 'mount allison university', 'pb', 'center for health technology & services research', 'compete', 'burroughs wellcome fund', 'portage health foundation', 'us highbush blueberry council', 'czech science foundation', 'stfc', 'autonomous community of the region of murcia', 'foncyt', 'world academy of sciences', 'united states department of energy', 'epigenmed', 'dost', 'nbf', 'college of chemistry', 'peg', 'japan epilepsy research foundation', 'janssen alzheimer immunotherapy research & development', 'aaes', 'immuno ...

# %%
result_df.loc['NER improved version I vs Crossref improved version I'] = pd.Series(result_match_count['NER improved version I vs Crossref improved version I'])
result_df.loc['NER improved version II vs Crossref improved version II'] = pd.Series(result_match_count['NER improved version II vs Crossref improved version II'])
result_df.loc['NER improved version III vs Crossref improved version III'] = pd.Series(result_match_count['NER improved version III vs Crossref improved version III'])
result_df.loc['NER improved version IV vs Crossref improved version IV'] = pd.Series(result_match_count['NER improved version IV vs Crossref improved version IV'])

# %%
result_df
# Out:
#                                                    NER_spacy_sm_org  \
# Crossref baseline vs NER baseline                           97859.0
# Crossref baseline vs NER improved version I                 92970.0
# Crossref baseline vs NER improved version II                97688.0
# Crossref baseline vs NER improved version III               96143.0
# Crossref baseline vs NER improved version IV                91058.0
# NER baseline vs Crossref improved version I                 97859.0
# NER baseline vs Crossref improved version II                97859.0
# NER baseline vs Crossref improved version III               97859.0
# NER baseline vs Crossref improved version IV                97859.0
# NER improved version I vs Crossref improved ver...          92970.0
# NER improved version II vs Crossref improved ve...          97688.0
# NER improved version III vs Crossref improved v...          96143.0
# NER improved version IV vs Crossref improved ve...          91058.0
#
#                                                    NER_spacy_sm_org_match  \
# Crossref baseline vs NER baseline                                  7762.0
# Crossref baseline vs NER improved version I                        9294.0
# Crossref baseline vs NER improved version II                       7348.0
# Crossref baseline vs NER improved version III                      7811.0
# Crossref baseline vs NER improved version IV                       8643.0
# NER baseline vs Crossref improved version I                        7244.0
# NER baseline vs Crossref improved version II                       7309.0
# NER baseline vs Crossref improved version III                      7516.0
# NER baseline vs Crossref improved version IV                       6611.0
# NER improved version I vs Crossref improved ver...                 9337.0
# NER improved version II vs Crossref improved ve...                 7774.0
# NER improved version III vs Crossref improved v...                 8143.0
# NER improved version IV vs Crossref improved ve...                 9734.0
#
#                                                    NER_spacy_sm_org_match_%  \
# Crossref baseline vs NER baseline                                   7.93182
# Crossref baseline vs NER improved version I                        9.996773
# Crossref baseline vs NER improved version II                       7.521906
# Crossref baseline vs NER improved version III                      8.124356
# Crossref baseline vs NER improved version IV                       9.491753
# NER baseline vs Crossref improved version I                        7.402487
# NER baseline vs Crossref improved version II                       7.468909
# NER baseline vs Crossref improved version III                      7.680438
# NER baseline vs Crossref improved version IV                       6.755638
# NER improved version I vs Crossref improved ver...                10.043025
# NER improved version II vs Crossref improved ve...                 7.957989
# NER improved version III vs Crossref improved v...                 8.469675
# NER improved version IV vs Crossref improved ve...                 10.68989
#
#                                                    NER_spacy_md_org  \
# Crossref baseline vs NER baseline                          102144.0
# Crossref baseline vs NER improved version I                 96974.0
# Crossref baseline vs NER improved version II               101971.0
# Crossref baseline vs NER improved version III              100323.0
# Crossref baseline vs NER improved version IV                94958.0
# NER baseline vs Crossref improved version I                102144.0
# NER baseline vs Crossref improved version II               102144.0
# NER baseline vs Crossref improved version III              102144.0
# NER baseline vs Crossref improved version IV               102144.0
# NER improved version I vs Crossref improved ver...          96974.0
# NER improved version II vs Crossref improved ve...         101971.0
# NER improved version III vs Crossref improved v...         100323.0
# NER improved version IV vs Crossref improved ve...          94958.0
#
#                                                    NER_spacy_md_org_match  \
# Crossref baseline vs NER baseline                                  8045.0
# Crossref baseline vs NER improved version I                        9522.0
# Crossref baseline vs NER improved version II                       7584.0
# Crossref baseline vs NER improved version III                      8057.0
# Crossref baseline vs NER improved version IV                       8809.0
# NER baseline vs Crossref improved version I                        7522.0
# NER baseline vs Crossref improved version II                       7533.0
# NER baseline vs Crossref improved version III                      7756.0
# NER baseline vs Crossref improved version IV                       6798.0
# NER improved version I vs Crossref improved ver...                 9567.0
# NER improved version II vs Crossref improved ve...                 8057.0
# NER improved version III vs Crossref improved v...                 8411.0
# NER improved version IV vs Crossref improved ve...                 9961.0
#
#                                                    NER_spacy_md_org_match_%  \
# Crossref baseline vs NER baseline                                  7.876136
# Crossref baseline vs NER improved version I                        9.819127
# Crossref baseline vs NER improved version II                       7.437409
# Crossref baseline vs NER improved version III                       8.03106
# Crossref baseline vs NER improved version IV                       9.276733
# NER baseline vs Crossref improved version I                        7.364113
# NER baseline vs Crossref improved version II                       7.374883
# NER baseline vs Crossref improved version III                      7.593202
# NER baseline vs Crossref improved version IV                        6.65531
# NER improved version I vs Crossref improved ver...                 9.865531
# NER improved version II vs Crossref improved ve...                 7.901266
# NER improved version III vs Crossref improved v...                  8.38392
# NER improved version IV vs Crossref improved ve...                10.489901
#
#                                                    NER_spacy_lg_org  \
# Crossref baseline vs NER baseline                          101777.0
# Crossref baseline vs NER improved version I                 96723.0
# Crossref baseline vs NER improved version II               101618.0
# Crossref baseline vs NER improved version III               99956.0
# Crossref baseline vs NER improved version IV                94712.0
# NER baseline vs Crossref improved version I                101777.0
# NER baseline vs Crossref improved version II               101777.0
# NER baseline vs Crossref improved version III              101777.0
# NER baseline vs Crossref improved version IV               101777.0
# NER improved version I vs Crossref improved ver...          96723.0
# NER improved version II vs Crossref improved ve...         101618.0
# NER improved version III vs Crossref improved v...          99956.0
# NER improved version IV vs Crossref improved ve...          94712.0
#
#                                                    NER_spacy_lg_org_match  \
# Crossref baseline vs NER baseline                                  8071.0
# Crossref baseline vs NER improved version I                        9544.0
# Crossref baseline vs NER improved version II                       7611.0
# Crossref baseline vs NER improved version III                      8064.0
# Crossref baseline vs NER improved version IV                       8805.0
# NER baseline vs Crossref improved version I                        7536.0
# NER baseline vs Crossref improved version II                       7558.0
# NER baseline vs Crossref improved version III                      7767.0
# NER baseline vs Crossref improved version IV                       6799.0
# NER improved version I vs Crossref improved ver...                 9593.0
# NER improved version II vs Crossref improved ve...                 8085.0
# NER improved version III vs Crossref improved v...                 8426.0
# NER improved version IV vs Crossref improved ve...                 9969.0
#
#                                                    NER_spacy_lg_org_match_%  \
# Crossref baseline vs NER baseline                                  7.930082
# Crossref baseline vs NER improved version I                        9.867353
# Crossref baseline vs NER improved version II                       7.489815
# Crossref baseline vs NER improved version III                       8.06755
# Crossref baseline vs NER improved version IV                       9.296604
# NER baseline vs Crossref improved version I                        7.404423
# NER baseline vs Crossref improved version II                       7.426039
# NER baseline vs Crossref improved version III                       7.63139
# NER baseline vs Crossref improved version IV                       6.680291
# NER improved version I vs Crossref improved ver...                 9.918013
# NER improved version II vs Crossref improved ve...                 7.956268
# NER improved version III vs Crossref improved v...                 8.429709
# NER improved version IV vs Crossref improved ve...                10.525593
#
#                                                    NER_Flair_org  \
# Crossref baseline vs NER baseline                        75465.0
# Crossref baseline vs NER improved version I              74910.0
# Crossref baseline vs NER improved version II             75256.0
# Crossref baseline vs NER improved version III            73372.0
# Crossref baseline vs NER improved version IV             72601.0
# NER baseline vs Crossref improved version I              75465.0
# NER baseline vs Crossref improved version II             75465.0
# NER baseline vs Crossref improved version III            75465.0
# NER baseline vs Crossref improved version IV             75465.0
# NER improved version I vs Crossref improved ver...       74910.0
# NER improved version II vs Crossref improved ve...       75256.0
# NER improved version III vs Crossref improved v...       73372.0
# NER improved version IV vs Crossref improved ve...       72601.0
#
#                                                    NER_Flair_org_match  \
# Crossref baseline vs NER baseline                              11682.0
# Crossref baseline vs NER improved version I                    11609.0
# Crossref baseline vs NER improved version II                   10882.0
# Crossref baseline vs NER improved version III                  11590.0
# Crossref baseline vs NER improved version IV                   10741.0
# NER baseline vs Crossref improved version I                    11584.0
# NER baseline vs Crossref improved version II                   10757.0
# NER baseline vs Crossref improved version III                  11426.0
# NER baseline vs Crossref improved version IV                   10418.0
# NER improved version I vs Crossref improved ver...             11661.0
# NER improved version II vs Crossref improved ve...             11680.0
# NER improved version III vs Crossref improved v...             12027.0
# NER improved version IV vs Crossref improved ve...             11999.0
#
#                                                    NER_Flair_org_match_%
# Crossref baseline vs NER baseline                              15.480024
# Crossref baseline vs NER improved version I                    15.497263
# Crossref baseline vs NER improved version II                   14.459977
# Crossref baseline vs NER improved version III                  15.796217
# Crossref baseline vs NER improved version IV                   14.794562
# NER baseline vs Crossref improved version I                    15.350162
# NER baseline vs Crossref improved version II                    14.25429
# NER baseline vs Crossref improved version III                  15.140794
# NER baseline vs Crossref improved version IV                   13.805075
# NER improved version I vs Crossref improved ver...              15.56668
# NER improved version II vs Crossref improved ve...             15.520357
# NER improved version III vs Crossref improved v...             16.391812
# NER improved version IV vs Crossref improved ve...             16.527321

# %% [markdown]
# **6. Storing the results in a dataframe**

# %%
t_1 = timeit.default_timer()
print("The time elapsed: ", t_1 - t_0)
# Out:
# The time elapsed:  1717.890178708

# %%
result_df.to_csv('../data/Result_Match.csv')

# %% [markdown]
# **7. Future work**
#
# 1. Random sampling from the tool output and perform subword analysis/matching appearing as substrings for some organizations. Check the original arcticles.
#
# 2. Trying out new NER tools
#
# 3. Traing own NER tool

# %%
result_df
# Out:
#                                                    NER_spacy_sm_org  \
# Crossref baseline vs NER baseline                           97859.0
# Crossref baseline vs NER improved version I                 92970.0
# Crossref baseline vs NER improved version II                97688.0
# Crossref baseline vs NER improved version III               96143.0
# Crossref baseline vs NER improved version IV                91058.0
# NER baseline vs Crossref improved version I                 97859.0
# NER baseline vs Crossref improved version II                97859.0
# NER baseline vs Crossref improved version III               97859.0
# NER baseline vs Crossref improved version IV                97859.0
# NER improved version I vs Crossref improved ver...          92970.0
# NER improved version II vs Crossref improved ve...          97688.0
# NER improved version III vs Crossref improved v...          96143.0
# NER improved version IV vs Crossref improved ve...          91058.0
#
#                                                    NER_spacy_sm_org_match  \
# Crossref baseline vs NER baseline                                  7762.0
# Crossref baseline vs NER improved version I                        9294.0
# Crossref baseline vs NER improved version II                       7348.0
# Crossref baseline vs NER improved version III                      7811.0
# Crossref baseline vs NER improved version IV                       8643.0
# NER baseline vs Crossref improved version I                        7244.0
# NER baseline vs Crossref improved version II                       7309.0
# NER baseline vs Crossref improved version III                      7516.0
# NER baseline vs Crossref improved version IV                       6611.0
# NER improved version I vs Crossref improved ver...                 9337.0
# NER improved version II vs Crossref improved ve...                 7774.0
# NER improved version III vs Crossref improved v...                 8143.0
# NER improved version IV vs Crossref improved ve...                 9734.0
#
#                                                    NER_spacy_sm_org_match_%  \
# Crossref baseline vs NER baseline                                   7.93182
# Crossref baseline vs NER improved version I                        9.996773
# Crossref baseline vs NER improved version II                       7.521906
# Crossref baseline vs NER improved version III                      8.124356
# Crossref baseline vs NER improved version IV                       9.491753
# NER baseline vs Crossref improved version I                        7.402487
# NER baseline vs Crossref improved version II                       7.468909
# NER baseline vs Crossref improved version III                      7.680438
# NER baseline vs Crossref improved version IV                       6.755638
# NER improved version I vs Crossref improved ver...                10.043025
# NER improved version II vs Crossref improved ve...                 7.957989
# NER improved version III vs Crossref improved v...                 8.469675
# NER improved version IV vs Crossref improved ve...                 10.68989
#
#                                                    NER_spacy_md_org  \
# Crossref baseline vs NER baseline                          102144.0
# Crossref baseline vs NER improved version I                 96974.0
# Crossref baseline vs NER improved version II               101971.0
# Crossref baseline vs NER improved version III              100323.0
# Crossref baseline vs NER improved version IV                94958.0
# NER baseline vs Crossref improved version I                102144.0
# NER baseline vs Crossref improved version II               102144.0
# NER baseline vs Crossref improved version III              102144.0
# NER baseline vs Crossref improved version IV               102144.0
# NER improved version I vs Crossref improved ver...          96974.0
# NER improved version II vs Crossref improved ve...         101971.0
# NER improved version III vs Crossref improved v...         100323.0
# NER improved version IV vs Crossref improved ve...          94958.0
#
#                                                    NER_spacy_md_org_match  \
# Crossref baseline vs NER baseline                                  8045.0
# Crossref baseline vs NER improved version I                        9522.0
# Crossref baseline vs NER improved version II                       7584.0
# Crossref baseline vs NER improved version III                      8057.0
# Crossref baseline vs NER improved version IV                       8809.0
# NER baseline vs Crossref improved version I                        7522.0
# NER baseline vs Crossref improved version II                       7533.0
# NER baseline vs Crossref improved version III                      7756.0
# NER baseline vs Crossref improved version IV                       6798.0
# NER improved version I vs Crossref improved ver...                 9567.0
# NER improved version II vs Crossref improved ve...                 8057.0
# NER improved version III vs Crossref improved v...                 8411.0
# NER improved version IV vs Crossref improved ve...                 9961.0
#
#                                                    NER_spacy_md_org_match_%  \
# Crossref baseline vs NER baseline                                  7.876136
# Crossref baseline vs NER improved version I                        9.819127
# Crossref baseline vs NER improved version II                       7.437409
# Crossref baseline vs NER improved version III                       8.03106
# Crossref baseline vs NER improved version IV                       9.276733
# NER baseline vs Crossref improved version I                        7.364113
# NER baseline vs Crossref improved version II                       7.374883
# NER baseline vs Crossref improved version III                      7.593202
# NER baseline vs Crossref improved version IV                        6.65531
# NER improved version I vs Crossref improved ver...                 9.865531
# NER improved version II vs Crossref improved ve...                 7.901266
# NER improved version III vs Crossref improved v...                  8.38392
# NER improved version IV vs Crossref improved ve...                10.489901
#
#                                                    NER_spacy_lg_org  \
# Crossref baseline vs NER baseline                          101777.0
# Crossref baseline vs NER improved version I                 96723.0
# Crossref baseline vs NER improved version II               101618.0
# Crossref baseline vs NER improved version III               99956.0
# Crossref baseline vs NER improved version IV                94712.0
# NER baseline vs Crossref improved version I                101777.0
# NER baseline vs Crossref improved version II               101777.0
# NER baseline vs Crossref improved version III              101777.0
# NER baseline vs Crossref improved version IV               101777.0
# NER improved version I vs Crossref improved ver...          96723.0
# NER improved version II vs Crossref improved ve...         101618.0
# NER improved version III vs Crossref improved v...          99956.0
# NER improved version IV vs Crossref improved ve...          94712.0
#
#                                                    NER_spacy_lg_org_match  \
# Crossref baseline vs NER baseline                                  8071.0
# Crossref baseline vs NER improved version I                        9544.0
# Crossref baseline vs NER improved version II                       7611.0
# Crossref baseline vs NER improved version III                      8064.0
# Crossref baseline vs NER improved version IV                       8805.0
# NER baseline vs Crossref improved version I                        7536.0
# NER baseline vs Crossref improved version II                       7558.0
# NER baseline vs Crossref improved version III                      7767.0
# NER baseline vs Crossref improved version IV                       6799.0
# NER improved version I vs Crossref improved ver...                 9593.0
# NER improved version II vs Crossref improved ve...                 8085.0
# NER improved version III vs Crossref improved v...                 8426.0
# NER improved version IV vs Crossref improved ve...                 9969.0
#
#                                                    NER_spacy_lg_org_match_%  \
# Crossref baseline vs NER baseline                                  7.930082
# Crossref baseline vs NER improved version I                        9.867353
# Crossref baseline vs NER improved version II                       7.489815
# Crossref baseline vs NER improved version III                       8.06755
# Crossref baseline vs NER improved version IV                       9.296604
# NER baseline vs Crossref improved version I                        7.404423
# NER baseline vs Crossref improved version II                       7.426039
# NER baseline vs Crossref improved version III                       7.63139
# NER baseline vs Crossref improved version IV                       6.680291
# NER improved version I vs Crossref improved ver...                 9.918013
# NER improved version II vs Crossref improved ve...                 7.956268
# NER improved version III vs Crossref improved v...                 8.429709
# NER improved version IV vs Crossref improved ve...                10.525593
#
#                                                    NER_Flair_org  \
# Crossref baseline vs NER baseline                        75465.0
# Crossref baseline vs NER improved version I              74910.0
# Crossref baseline vs NER improved version II             75256.0
# Crossref baseline vs NER improved version III            73372.0
# Crossref baseline vs NER improved version IV             72601.0
# NER baseline vs Crossref improved version I              75465.0
# NER baseline vs Crossref improved version II             75465.0
# NER baseline vs Crossref improved version III            75465.0
# NER baseline vs Crossref improved version IV             75465.0
# NER improved version I vs Crossref improved ver...       74910.0
# NER improved version II vs Crossref improved ve...       75256.0
# NER improved version III vs Crossref improved v...       73372.0
# NER improved version IV vs Crossref improved ve...       72601.0
#
#                                                    NER_Flair_org_match  \
# Crossref baseline vs NER baseline                              11682.0
# Crossref baseline vs NER improved version I                    11609.0
# Crossref baseline vs NER improved version II                   10882.0
# Crossref baseline vs NER improved version III                  11590.0
# Crossref baseline vs NER improved version IV                   10741.0
# NER baseline vs Crossref improved version I                    11584.0
# NER baseline vs Crossref improved version II                   10757.0
# NER baseline vs Crossref improved version III                  11426.0
# NER baseline vs Crossref improved version IV                   10418.0
# NER improved version I vs Crossref improved ver...             11661.0
# NER improved version II vs Crossref improved ve...             11680.0
# NER improved version III vs Crossref improved v...             12027.0
# NER improved version IV vs Crossref improved ve...             11999.0
#
#                                                    NER_Flair_org_match_%
# Crossref baseline vs NER baseline                              15.480024
# Crossref baseline vs NER improved version I                    15.497263
# Crossref baseline vs NER improved version II                   14.459977
# Crossref baseline vs NER improved version III                  15.796217
# Crossref baseline vs NER improved version IV                   14.794562
# NER baseline vs Crossref improved version I                    15.350162
# NER baseline vs Crossref improved version II                    14.25429
# NER baseline vs Crossref improved version III                  15.140794
# NER baseline vs Crossref improved version IV                   13.805075
# NER improved version I vs Crossref improved ver...              15.56668
# NER improved version II vs Crossref improved ve...             15.520357
# NER improved version III vs Crossref improved v...             16.391812
# NER improved version IV vs Crossref improved ve...             16.527321
